# %%
import pandas as pd
import numpy as np
data = pd.read_csv('./from_predictions/top_corr_data.csv')
X = data.iloc[:,0:49]  #independent colum
y = data.iloc[:,-1]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(14).plot(kind='barh')
plt.show()
# Out:
# [0.01921295 0.02703974 0.0208936  0.01940306 0.02195536 0.02116494
#  0.02400719 0.02981845 0.02146308 0.01984014 0.01891607 0.01985555
#  0.01936002 0.02019654 0.01953705 0.02153542 0.02132712 0.01846938
#  0.01911093 0.01940285 0.019551   0.01946313 0.01816163 0.01990946
#  0.01931778 0.01929428 0.0185834  0.01834135 0.01892043 0.01951227
#  0.02123546 0.0199266  0.02160556 0.02036692 0.01965391 0.01787363
#  0.01962608 0.01782878 0.01931136 0.02131609 0.02195182 0.01812586
#  0.01763065 0.02185226 0.02149082 0.02309427 0.02162793 0.02196739
#  0.01995042]

# %%
feat_importances.nlargest(20)
# Out:
# original_glcm_Correlation.2                0.029818
# Age                                        0.027040
# original_glszm_ZoneEntropy.1               0.024007
# original_shape_MinorAxisLength             0.023094
# original_shape_LeastAxisLength.3           0.021967
# original_shape_SurfaceArea.1               0.021955
# original_shape_MinorAxisLength.1           0.021952
# original_glcm_Idn.2                        0.021852
# original_shape_MinorAxisLength.3           0.021628
# original_shape_Maximum2DDiameterSlice.5    0.021606
# original_glrlm_RunLengthNonUniformity.3    0.021535
# original_glcm_Idmn.2                       0.021491
# original_glszm_GrayLevelNonUniformity.5    0.021463
# original_shape_Maximum2DDiameterSlice.3    0.021327
# original_shape_MinorAxisLength.4           0.021316
# original_shape_Maximum2DDiameterColumn     0.021235
# original_shape_SurfaceArea.4               0.021165
# original_shape_LeastAxisLength.5           0.020894
# original_shape_Maximum2DDiameterRow.2      0.020367
# original_shape_Maximum2DDiameterRow.3      0.020197
# dtype: float64

# %%
corr = pd.read_csv('./from_predictions/corr.csv')
imp = corr.tail(50)['Unnamed: 0']

# %%
data = pd.read_csv('./from_predictions/all_data_filled_r.csv')
data[imp].to_csv('top_corr_data.csv')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
data = pd.read_csv('./from_predictions/top_corr_data.csv')
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(50,50))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
corrmat.to_csv('./from_predictions/corr_for_50.csv')

# %%
new_imp = ['original_shape_LeastAxisLength.2', 'original_shape_SurfaceArea.4', 'original_shape_MinorAxisLength.5']
