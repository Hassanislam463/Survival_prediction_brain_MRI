# %% [markdown]
# ### Imports:

# %%
import pickle

from functools import partial

from tensorflow.keras.layers import Input, LeakyReLU, Add, UpSampling3D, Activation, SpatialDropout3D
from keras.optimizer_v2 import adam
from keras.optimizer_v2 import rmsprop 

import pandas as pd

import numpy as np
from keras import backend as K
from keras import Input
from keras import Model
from keras.layers import Conv3D, MaxPooling3D, UpSampling3D, Activation, BatchNormalization, PReLU, Flatten, Dense, GlobalAveragePooling3D

# K.set_image_dim_ordering('th')
# K.set_image_dim_ordering('tf')
K.set_image_data_format('channels_first')

try:
    from keras.engine import merge
except ImportError:
    from keras.layers.merge import concatenate

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print(len(device_lib.list_local_devices()))
# Out:
# C:\Users\HassanIslam\anaconda3\envs\FYP\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\HassanIslam\anaconda3\envs\FYP\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\HassanIslam\anaconda3\envs\FYP\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3796633128729504359
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10091102208
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4195951953474789381
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# 2

# %% [markdown]
# ### Reading in survival data.csv:

# %%
survival_data = pd.read_csv('survival_data_filled.csv')
# m = survival_data['Age'].mean()
# survival_data['Age'].fillna(value=m, inplace=True)
# survival_data['Survival'] = survival_data['Survival'].fillna(0)
# survival_data.to_csv('./features/survival_data_filled.csv')

# %%
ID = 'BraTS19_CBICA_ABN_1'
survival_data[survival_data.BraTS19ID==ID].Survival.astype(int).values.item(0)
# Out:
# 1278

# %% [markdown]
# ### Make tumor type dictionary:

# %%
tumor_type_dict = {}

# %%
import os

HGG_dir_list = next(os.walk('./dataCorrected/'))[1]
# print(len(HGG_dir_list))
# LGG_dir_list = next(os.walk('./LGG/'))[1]
# print(len(LGG_dir_list))


for patientID in HGG_dir_list:
#     print(patientID)
    if patientID in HGG_dir_list:
#         tumor_type_dict[patientID] = "HGG"
        tumor_type_dict[patientID] = 0
    elif patientID in LGG_dir_list:
#         tumor_type_dict[patientID] = "LGG"
        tumor_type_dict[patientID] = 1

print(len(tumor_type_dict))
# tumor_type_dict[(HGG_dir_list+LGG_dir_list)[0]]
# Out:
# 257

# %% [markdown]
# ### Calculating metrics:

# %%
def dice_coefficient(y_true, y_pred, smooth=1.):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coefficient_loss(y_true, y_pred):
    return -dice_coefficient(y_true, y_pred)


def weighted_dice_coefficient(y_true, y_pred, axis=(-3, -2, -1), smooth=0.00001):
    """
    Weighted dice coefficient. Default axis assumes a "channels first" data structure
    :param smooth:
    :param y_true:
    :param y_pred:
    :param axis:
    :return:
    """
    return K.mean(2. * (K.sum(y_true * y_pred,
                              axis=axis) + smooth/2)/(K.sum(y_true,
                                                            axis=axis) + K.sum(y_pred,
                                                                               axis=axis) + smooth))


def weighted_dice_coefficient_loss(y_true, y_pred):
    return -weighted_dice_coefficient(y_true, y_pred)


def label_wise_dice_coefficient(y_true, y_pred, label_index):
    return dice_coefficient(y_true[:, label_index], y_pred[:, label_index])


def get_label_dice_coefficient_function(label_index):
    f = partial(label_wise_dice_coefficient, label_index=label_index)
    f.__setattr__('__name__', 'label_{0}_dice_coef'.format(label_index))
    return f


dice_coef = dice_coefficient
dice_coef_loss = dice_coefficient_loss

# %%
def create_convolution_block(input_layer, n_filters, batch_normalization=False, kernel=(3, 3, 3), activation=None,
                             padding='same', strides=(1, 1, 1), instance_normalization=False):
    """
    :param strides:
    :param input_layer:
    :param n_filters:
    :param batch_normalization:
    :param kernel:
    :param activation: Keras activation layer to use. (default is 'relu')
    :param padding:
    :return:
    """
    layer = Conv3D(n_filters, kernel, padding=padding, strides=strides)(input_layer)
    if batch_normalization:
        layer = BatchNormalization(axis=1)(layer)
    elif instance_normalization:
        try:
            from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
        except ImportError:
            raise ImportError("Install keras_contrib in order to use instance normalization."
                              "\nTry: pip install git+https://www.github.com/farizrahman4u/keras-contrib.git")
        layer = InstanceNormalization(axis=1)(layer)
    if activation is None:
        return Activation('relu')(layer)
    else:
        return activation()(layer)


def compute_level_output_shape(n_filters, depth, pool_size, image_shape):
    """
    Each level has a particular output shape based on the number of filters used in that level and the depth or number 
    of max pooling operations that have been done on the data at that point.
    :param image_shape: shape of the 3d image.
    :param pool_size: the pool_size parameter used in the max pooling operation.
    :param n_filters: Number of filters used by the last node in a given level.
    :param depth: The number of levels down in the U-shaped model a given node is.
    :return: 5D vector of the shape of the output node 
    """
    output_image_shape = np.asarray(np.divide(image_shape, np.power(pool_size, depth)), dtype=np.int32).tolist()
    return tuple([None, n_filters] + output_image_shape)


def get_up_convolution(n_filters, pool_size, kernel_size=(2, 2, 2), strides=(2, 2, 2),
                       deconvolution=False):
    if deconvolution:
        return Deconvolution3D(filters=n_filters, kernel_size=kernel_size,
                               strides=strides)
    else:
        return UpSampling3D(size=pool_size)

def create_localization_module(input_layer, n_filters):
    convolution1 = create_convolution_block(input_layer, n_filters)
    convolution2 = create_convolution_block(convolution1, n_filters, kernel=(1, 1, 1))
    return convolution2


def create_up_sampling_module(input_layer, n_filters, size=(2, 2, 2)):
    up_sample = UpSampling3D(size=size)(input_layer)
    convolution = create_convolution_block(up_sample, n_filters)
    return convolution


def create_context_module(input_layer, n_level_filters, dropout_rate=0.3, data_format="channels_first"):
    convolution1 = create_convolution_block(input_layer=input_layer, n_filters=n_level_filters)
    dropout = SpatialDropout3D(rate=dropout_rate, data_format=data_format)(convolution1)
    convolution2 = create_convolution_block(input_layer=dropout, n_filters=n_level_filters)
    return convolution2


create_convolution_block = partial(create_convolution_block, activation=LeakyReLU, instance_normalization=True)

# %% [markdown]
# ### Make the labels and test train dictionaries:

# %%
# from glob import glob
# paths = glob('/Users/etheredgej/Desktop/MICCAI_BraTS17_Data_Training/train/HGG/*/')
# print(paths)

import os
HGG_dir_list = next(os.walk('./dataCorrected/'))[1]
print(len(HGG_dir_list))
# LGG_dir_list = next(os.walk('./LGG/'))[1]
# print(len(LGG_dir_list))
# Out:
# 257

# %% [markdown]
# ### Dictionary for all samples:

# %%
completelist = HGG_dir_list

# %%
# completelist = HGG_dir_list + LGG_dir_list

# completelist = list(survival_data.Brats17ID.copy())

# print(completelist[0:4])
np.random.shuffle(completelist) # shuffles in place
# print(completelist[0:4])

partition={}

holdout_percentage=0.15
partition['holdout']=completelist[0:int(len(completelist)*holdout_percentage)]
trainlist=completelist[int(len(completelist)*holdout_percentage):len(completelist)]

train_percentage=0.7
partition['train']=trainlist[0:int(len(trainlist)*train_percentage)]
partition['test']=trainlist[int(len(trainlist)*train_percentage):len(trainlist)]


labels={}
# HGG=0
# LGG=1
for directory in HGG_dir_list:
    labels[directory]=0
# for directory in LGG_dir_list:
#     labels[directory]=1
    
print(len(partition['holdout']))
print(len(partition['train']))
print(len(partition['test']))
# Out:
# 38
# 153
# 66

# %%
partition['holdout']
# Out:
# ['BraTS19_TCIA01_150_1',
#  'BraTS19_TCIA08_280_1',
#  'BraTS19_CBICA_AOZ_1',
#  'BraTS19_TCIA01_186_1',
#  'BraTS19_TCIA02_377_1',
#  'BraTS19_TCIA02_368_1',
#  'BraTS19_TCIA02_151_1',
#  'BraTS19_CBICA_AXM_1',
#  'BraTS19_TCIA02_394_1',
#  'BraTS19_2013_23_1',
#  'BraTS19_CBICA_AUX_1',
#  'BraTS19_TCIA06_603_1',
#  'BraTS19_CBICA_AQV_1',
#  'BraTS19_CBICA_AUQ_1',
#  'BraTS19_TCIA08_234_1',
#  'BraTS19_TCIA02_135_1',
#  'BraTS19_TCIA06_372_1',
#  'BraTS19_CBICA_ANG_1',
#  'BraTS19_TCIA02_171_1',
#  'BraTS19_CBICA_ASR_1',
#  'BraTS19_TCIA01_390_1',
#  'BraTS19_CBICA_BNR_1',
#  'BraTS19_CBICA_ABN_1',
#  'BraTS19_CBICA_BGO_1',
#  'BraTS19_CBICA_AAL_1',
#  'BraTS19_CBICA_ATX_1',
#  'BraTS19_CBICA_AYA_1',
#  'BraTS19_2013_13_1',
#  'BraTS19_CBICA_AVV_1',
#  'BraTS19_TCIA08_242_1',
#  'BraTS19_CBICA_AQR_1',
#  'BraTS19_TCIA02_607_1',
#  'BraTS19_CBICA_AXO_1',
#  'BraTS19_TCIA02_118_1',
#  'BraTS19_2013_7_1',
#  'BraTS19_CBICA_AOH_1',
#  'BraTS19_TCIA01_401_1',
#  'BraTS19_CBICA_BIC_1']

# %% [markdown]
# ### Dictionary for the samples with survival data:

# %%
completelist = HGG_dir_list

completelist = list(survival_data.BraTS19ID.copy())

# print(completelist[0:4])
np.random.shuffle(completelist) # shuffles in place
# print(completelist[0:4])

subpartition={}

holdout_percentage=0.15
subpartition['holdout']=completelist[0:int(len(completelist)*holdout_percentage)]
trainlist=completelist[int(len(completelist)*holdout_percentage):len(completelist)]

train_percentage=0.7
subpartition['train']=trainlist[0:int(len(trainlist)*train_percentage)]
subpartition['test']=trainlist[int(len(trainlist)*train_percentage):len(trainlist)]


labels={}
# HGG=0
# LGG=1
for directory in HGG_dir_list:
    labels[directory]=0
# for directory in LGG_dir_list:
#     labels[directory]=1
    
print(len(subpartition['holdout']))
print(len(subpartition['train']))
print(len(subpartition['test']))
# Out:
# 38
# 153
# 66

# %%
subpartition['holdout']
# len(survival_data.Brats17ID)
# len(set.intersection(set(completelist),set(survival_data.Brats17ID)))
# Out:
# ['BraTS19_CBICA_BFP_1',
#  'BraTS19_TCIA01_401_1',
#  'BraTS19_TCIA03_375_1',
#  'BraTS19_CBICA_AWH_1',
#  'BraTS19_CBICA_ATF_1',
#  'BraTS19_CBICA_ASE_1',
#  'BraTS19_TCIA02_473_1',
#  'BraTS19_CBICA_ASF_1',
#  'BraTS19_CBICA_AQR_1',
#  'BraTS19_2013_22_1',
#  'BraTS19_CBICA_BGE_1',
#  'BraTS19_CBICA_AQT_1',
#  'BraTS19_CBICA_ARW_1',
#  'BraTS19_TCIA01_180_1',
#  'BraTS19_TCIA01_390_1',
#  'BraTS19_TCIA01_335_1',
#  'BraTS19_CBICA_BGN_1',
#  'BraTS19_TCIA01_412_1',
#  'BraTS19_CBICA_ASW_1',
#  'BraTS19_TCIA01_131_1',
#  'BraTS19_2013_4_1',
#  'BraTS19_TMC_12866_1',
#  'BraTS19_CBICA_AUA_1',
#  'BraTS19_TCIA02_208_1',
#  'BraTS19_CBICA_BEM_1',
#  'BraTS19_CBICA_APZ_1',
#  'BraTS19_2013_17_1',
#  'BraTS19_CBICA_AVG_1',
#  'BraTS19_CBICA_AZD_1',
#  'BraTS19_2013_25_1',
#  'BraTS19_TCIA08_105_1',
#  'BraTS19_TCIA08_205_1',
#  'BraTS19_CBICA_AUN_1',
#  'BraTS19_CBICA_ALX_1',
#  'BraTS19_TCIA08_469_1',
#  'BraTS19_2013_26_1',
#  'BraTS19_TCIA01_147_1',
#  'BraTS19_CBICA_BJY_1']

# %% [markdown]
# ### crop_img function:

# %%
# import numpy as np
# from nilearn.image.image import check_niimg
# from nilearn.image.image import _crop_img_to as crop_img_to


# def crop_img(img, rtol=1e-8, copy=True, return_slices=False):
#     """Crops img as much as possible
#     Will crop img, removing as many zero entries as possible
#     without touching non-zero entries. Will leave one voxel of
#     zero padding around the obtained non-zero area in order to
#     avoid sampling issues later on.
#     Parameters
#     ----------
#     img: Niimg-like object
#         See http://nilearn.github.io/manipulating_images/input_output.html
#         img to be cropped.
#     rtol: float
#         relative tolerance (with respect to maximal absolute
#         value of the image), under which values are considered
#         negligeable and thus croppable.
#     copy: boolean
#         Specifies whether cropped data is copied or not.
#     return_slices: boolean
#         If True, the slices that define the cropped image will be returned.
#     Returns
#     -------
#     cropped_img: image
#         Cropped version of the input image
#     """

#     img = check_niimg(img)
#     data = img.get_data()
#     infinity_norm = max(-data.min(), data.max())
#     passes_threshold = np.logical_or(data < -rtol * infinity_norm,
#                                      data > rtol * infinity_norm)

#     if data.ndim == 4:
#         passes_threshold = np.any(passes_threshold, axis=-1)
#     coords = np.array(np.where(passes_threshold))
#     start = coords.min(axis=1)
#     end = coords.max(axis=1) + 1

#     # pad with one voxel to avoid resampling problems
#     start = np.maximum(start - 1, 0)
#     end = np.minimum(end + 1, data.shape[:3])

#     slices = [slice(s, e) for s, e in zip(start, end)]

#     if return_slices:
#         return slices

#     return crop_img_to(img, slices, copy=copy)

# %% [markdown]
# ### Save all the cropped images as pickled numpy arrays:

# %%
# import pickle
# import numpy as np
# import nibabel as nib

# for i, ID in enumerate(completelist):
#     print("Reading",completelist[i])

#     img1 = './dataCorrected/' + ID + '/' + ID + '_flair.nii.gz'
#     img2 = './dataCorrected/' + ID +  '/' + ID + '_t1.nii.gz'
#     img3 = './dataCorrected/' + ID +  '/' + ID + '_t1ce.nii.gz'
#     img4 = './dataCorrected/' + ID +  '/' + ID + '_t2.nii.gz'
#     img5 = './data/' + ID +  '/' + ID + '_seg.nii.gz'

#     newimage = nib.concat_images([img1, img2, img3, img4, img5])
#     cropped = crop_img(newimage)         
#     img_array = np.array(cropped.dataobj)
#     z = np.rollaxis(img_array, 3, 0)

#     padded_image = np.zeros((5,160,192,160))
#     padded_image[:z.shape[0],:z.shape[1],:z.shape[2],:z.shape[3]] = z

#     a,b,c,d,seg_mask = np.split(padded_image, 5, axis=0)

#     images = np.concatenate([a,b,c,d], axis=0)

#     # print("images shape:", images.shape, "images values:", np.unique(images.astype(int)))

#     # split the channels:
#     # seg_mask_1 = copy.deepcopy(seg_mask.astype(int))
#     seg_mask_1 = np.zeros((1,160,192,160))
#     seg_mask_1[seg_mask.astype(int) == 1] = 1
#     seg_mask_2 = np.zeros((1,160,192,160))
#     seg_mask_2[seg_mask.astype(int) == 2] = 1
#     seg_mask_3 = np.zeros((1,160,192,160))
#     seg_mask_3[seg_mask.astype(int) == 4] = 1
#     seg_mask_3ch = np.concatenate([seg_mask_1,seg_mask_2,seg_mask_3], axis=0).astype(int)

#     # 1) the "enhancing tumor" (ET), 2) the "tumor core" (TC), and 3) the "whole tumor" (WT) 
#     # The ET is described by areas that show hyper-intensity in T1Gd when compared to T1, but also when compared to “healthy” white matter in T1Gd. The TC describes the bulk of the tumor, which is what is typically resected. The TC entails the ET, as well as the necrotic (fluid-filled) and the non-enhancing (solid) parts of the tumor. The appearance of the necrotic (NCR) and the non-enhancing (NET) tumor core is typically hypo-intense in T1-Gd when compared to T1. The WT describes the complete extent of the disease, as it entails the TC and the peritumoral edema (ED), which is typically depicted by hyper-intense signal in FLAIR.
#     # The labels in the provided data are: 
#     # 1 for NCR & NET (necrotic (NCR) and the non-enhancing (NET) tumor core) = TC ("tumor core")
#     # 2 for ED ("peritumoral edema")
#     # 4 for ET ("enhancing tumor")
#     # 0 for everything else

# #     X[i,] = images
# #     y1[i,] = seg_mask_3ch
#     pickle.dump( images, open( "D:\croppedFiles/%s_images.pkl"%(ID), "wb" ) )
#     pickle.dump( seg_mask_3ch, open( "D:\croppedFiles/%s_seg_mask_3ch.pkl"%(ID), "wb" ) )
#     print("Saving", i+1,completelist[i], "of", len(completelist))

# %% [markdown]
# ### Data generator all samples (1 predictions):

# %% [markdown]
# ### Data generator all samples (2 predictions):

# %% [markdown]
# ### Data generator for samples with survival data (3 predictions, subset of images):

# %%
# https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly.html

import numpy as np
import keras
import nibabel as nib

class SubDataGenerator(keras.utils.data_utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, batch_size=1, dim=(240,240,155), n_channels=4,
                 n_classes=3, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y1, y2 = self.__data_generation(list_IDs_temp)

        return X, [y1, y2]

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, self.n_channels, *self.dim))
        y1 = np.empty((self.batch_size, 3, *self.dim))
        y2 = np.empty(self.batch_size)

        # Generate data
        # Decode and load the data
        for i, ID in enumerate(list_IDs_temp):

            # 1) the "enhancing tumor" (ET), 2) the "tumor core" (TC), and 3) the "whole tumor" (WT) 
            # The ET is described by areas that show hyper-intensity in T1Gd when compared to T1, but also when compared to “healthy” white matter in T1Gd. The TC describes the bulk of the tumor, which is what is typically resected. The TC entails the ET, as well as the necrotic (fluid-filled) and the non-enhancing (solid) parts of the tumor. The appearance of the necrotic (NCR) and the non-enhancing (NET) tumor core is typically hypo-intense in T1-Gd when compared to T1. The WT describes the complete extent of the disease, as it entails the TC and the peritumoral edema (ED), which is typically depicted by hyper-intense signal in FLAIR.
            # The labels in the provided data are: 
            # 1 for NCR & NET (necrotic (NCR) and the non-enhancing (NET) tumor core) = TC ("tumor core")
            # 2 for ED ("peritumoral edema")
            # 4 for ET ("enhancing tumor")
            # 0 for everything else

            X[i,] = pickle.load( open( "D:\croppedFiles/%s_images.pkl"%(ID), "rb" ) )
            y1[i,] = pickle.load( open( "D:\croppedFiles/%s_seg_mask_3ch.pkl"%(ID), "rb" ) )            
            y2[i,] = survival_data[survival_data.BraTS19ID==ID].Survival.astype(int).values.item(0)

        return X, y1, y2

# %%
# import numpy as np

# from keras.models import Sequential
# from my_classes import DataGenerator

# %%
ID = LGG_dir_list[0]
type(tumor_type_dict[ID])

# %% [markdown]
# ### Single prediction compilation:

# %%
# # change the number of labels?
# # loss_function={'activation_block': weighted_dice_coefficient_loss, 'survival_block': 'mean_squared_error'}
# # selected_optimizer = RMSprop
# # selected_initial_learning_rate = 5e-4

# model = isensee2017_model(input_shape=(4, 160, 192, 160), n_base_filters=12, depth=5, dropout_rate=0.3,
#                       n_segmentation_levels=3, n_labels=3, activation_name="sigmoid")

# model.compile(optimizer=RMSprop(lr=5e-4), 
#               loss={'activation_block': weighted_dice_coefficient_loss}, 
#               loss_weights={'activation_block': 1.},
#              metrics={'activation_block': ['accuracy',weighted_dice_coefficient, dice_coefficient]})

# model.summary(line_length=150) # add the parameter that allows me to show everything instead of cutting it off

# %%
# change the number of labels?
# loss_function={'activation_block': weighted_dice_coefficient_loss, 'survival_block': 'mean_squared_error'}
# selected_optimizer = RMSprop
# selected_initial_learning_rate = 5e-4



input_shape=(4, 160, 192, 160)
n_base_filters=8
depth=5
dropout_rate=0.3
n_segmentation_levels=3
n_labels=3
activation_name="sigmoid"

"""
This function builds a model proposed by Isensee et al. for the BRATS 2017 competition:
https://www.cbica.upenn.edu/sbia/Spyridon.Bakas/MICCAI_BraTS/MICCAI_BraTS_2017_proceedings_shortPapers.pdf
This network is highly similar to the model proposed by Kayalibay et al. "CNN-based Segmentation of Medical
Imaging Data", 2017: https://arxiv.org/pdf/1701.03056.pdf
:param input_shape:
:param n_base_filters:
:param depth:
:param dropout_rate:
:param n_segmentation_levels:
:param n_labels:
:param optimizer:
:param initial_learning_rate:
:param loss_function:
:param activation_name:
:return:
"""
inputs = Input(input_shape)

current_layer = inputs
level_output_layers = list()
level_filters = list()
for level_number in range(depth):
    n_level_filters = (2**level_number) * n_base_filters
    level_filters.append(n_level_filters)

    if current_layer is inputs:
        in_conv = create_convolution_block(current_layer, n_level_filters)
    else:
        in_conv = create_convolution_block(current_layer, n_level_filters, strides=(2, 2, 2))

    context_output_layer = create_context_module(in_conv, n_level_filters, dropout_rate=dropout_rate)

    summation_layer = Add()([in_conv, context_output_layer])
    level_output_layers.append(summation_layer)
    current_layer = summation_layer

segmentation_layers = list()
for level_number in range(depth - 2, -1, -1):
    up_sampling = create_up_sampling_module(current_layer, level_filters[level_number])
    concatenation_layer = concatenate([level_output_layers[level_number], up_sampling], axis=1)
    localization_output = create_localization_module(concatenation_layer, level_filters[level_number])
    current_layer = localization_output
    if level_number < n_segmentation_levels:
        segmentation_layers.insert(0, create_convolution_block(current_layer, n_filters=n_labels, kernel=(1, 1, 1)))

for l in segmentation_layers:
    print(l.shape)
        
output_layer = None
for level_number in reversed(range(n_segmentation_levels)):
    segmentation_layer = segmentation_layers[level_number]
    if output_layer is None:
        output_layer = segmentation_layer
    else:
        print(level_number)
        output_layer = Add()([output_layer, segmentation_layer])

    if level_number > 0:
        output_layer = UpSampling3D(size=(2, 2, 2))(output_layer)

activation_block = Activation(activation = activation_name, name='activation_block')(output_layer)
#     survival_block = Activation("linear")(summation_layer)
#     activation_block = Dense(1, activation=activation_name, name='activation_block')(output_layer)
#     flatten = Flatten(name='flatten')(summation_layer)
#     survival_block = Dense(1, activation='linear', name='survival_block')(flatten)

survival_conv_1 = Conv3D(filters=n_level_filters, kernel_size=(3, 3, 3), padding='same', strides=(1, 1, 1), name='survival_conv_1')(summation_layer)
survival_conv_2 = Conv3D(filters=n_level_filters, kernel_size=(3, 3, 3), padding='same', strides=(1, 1, 1), name='survival_conv_2')(survival_conv_1)
dropout = SpatialDropout3D(rate=dropout_rate, data_format='channels_first', name='dropout')(survival_conv_2)
survival_conv_3 = Conv3D(filters=n_level_filters, kernel_size=(3, 3, 3), padding='same', strides=(1, 1, 1), name='survival_conv_3')(dropout)
survival_GAP = GlobalAveragePooling3D(name='survival_GAP')(survival_conv_3)
#     flatten = Flatten(name='flatten')(survival_GAP)
#     survival_block = Activation("linear", name='survival_block')(flatten)
survival_block = Dense(1, activation='linear', name='survival_block')(survival_GAP)

tumortype_conv_1 = Conv3D(filters=n_level_filters, kernel_size=(3, 3, 3), padding='same', strides=(1, 1, 1), name='tumortype_conv_1')(summation_layer)
tumortype_conv_2 = Conv3D(filters=n_level_filters, kernel_size=(3, 3, 3), padding='same', strides=(1, 1, 1), name='tumortype_conv_2')(tumortype_conv_1)
tumortype_dropout = SpatialDropout3D(rate=dropout_rate, data_format='channels_first', name='tumortype_dropout')(tumortype_conv_2)
tumortype_conv_3 = Conv3D(filters=n_level_filters, kernel_size=(3, 3, 3), padding='same', strides=(1, 1, 1), name='tumortype_conv_3')(tumortype_dropout)
tumortype_GAP = GlobalAveragePooling3D(name='tumortype_GAP')(tumortype_conv_3)
#     flatten = Flatten(name='flatten')(tumortype_GAP)
#     tumortype_block = Activation("linear", name='tumortype_block')(flatten)
tumortype_block = Dense(1, activation='sigmoid', name='tumortype_block')(tumortype_GAP)  

model = Model(inputs=inputs, outputs=[activation_block])
#     model.compile(optimizer=optimizer(lr=initial_learning_rate), loss=loss_function)
#     loss={'activation_block': 'binary_crossentropy', 'survival_block': 'mean_squared_error'}
# assign weights and loss as dictionaries
# functional-api-guide
# loss_weights define the ratio of how much I care about optimizing each one

# model.load_weights("./weights/1pred_weights.25--0.08.hdf5", by_name=True) # the by_name=True allows you to use a different architecture and bring in the weights from the matching layers 

model.compile(optimizer="adam", 
              loss={'activation_block': weighted_dice_coefficient_loss}, 
              loss_weights={'activation_block': 1.},
             metrics={'activation_block': ['accuracy',weighted_dice_coefficient, dice_coefficient]})

model.summary() # add the parameter that allows me to show everything instead of cutting it off
# Out:
# (None, 3, 160, 192, 160)
# (None, 3, 80, 96, 80)
# (None, 3, 40, 48, 40)
# 1
# 0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4, 160, 192, 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 8, 160, 192,  872         input_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization (Instanc (None, 8, 160, 192,  16          conv3d[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu (TFOpLambda)   (None, 8, 160, 192,  0           instance_normalization[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 8, 160, 192,  1736        tf.nn.leaky_relu[0][0]
# __________________________________________________________________________________________________
# instance_normalization_1 (Insta (None, 8, 160, 192,  16          conv3d_1[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_1 (TFOpLambda) (None, 8, 160, 192,  0           instance_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.identity (TFOpLambda)        (None, 8, 160, 192,  0           tf.nn.leaky_relu_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 8, 160, 192,  1736        tf.identity[0][0]
# __________________________________________________________________________________________________
# instance_normalization_2 (Insta (None, 8, 160, 192,  16          conv3d_2[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_2 (TFOpLambda) (None, 8, 160, 192,  0           instance_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 8, 160, 192,  0           tf.nn.leaky_relu[0][0]
#                                                                  tf.nn.leaky_relu_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 16, 80, 96, 8 3472        tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# instance_normalization_3 (Insta (None, 16, 80, 96, 8 32          conv3d_3[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_3 (TFOpLambda) (None, 16, 80, 96, 8 0           instance_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 16, 80, 96, 8 6928        tf.nn.leaky_relu_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_4 (Insta (None, 16, 80, 96, 8 32          conv3d_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_4 (TFOpLambda) (None, 16, 80, 96, 8 0           instance_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf.identity_1 (TFOpLambda)      (None, 16, 80, 96, 8 0           tf.nn.leaky_relu_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 16, 80, 96, 8 6928        tf.identity_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_5 (Insta (None, 16, 80, 96, 8 32          conv3d_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_5 (TFOpLambda) (None, 16, 80, 96, 8 0           instance_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 16, 80, 96, 8 0           tf.nn.leaky_relu_3[0][0]
#                                                                  tf.nn.leaky_relu_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 32, 40, 48, 4 13856       tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_6 (Insta (None, 32, 40, 48, 4 64          conv3d_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_6 (TFOpLambda) (None, 32, 40, 48, 4 0           instance_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 32, 40, 48, 4 27680       tf.nn.leaky_relu_6[0][0]
# __________________________________________________________________________________________________
# instance_normalization_7 (Insta (None, 32, 40, 48, 4 64          conv3d_7[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_7 (TFOpLambda) (None, 32, 40, 48, 4 0           instance_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf.identity_2 (TFOpLambda)      (None, 32, 40, 48, 4 0           tf.nn.leaky_relu_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 32, 40, 48, 4 27680       tf.identity_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_8 (Insta (None, 32, 40, 48, 4 64          conv3d_8[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_8 (TFOpLambda) (None, 32, 40, 48, 4 0           instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 32, 40, 48, 4 0           tf.nn.leaky_relu_6[0][0]
#                                                                  tf.nn.leaky_relu_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 64, 20, 24, 2 55360       tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_9 (Insta (None, 64, 20, 24, 2 128         conv3d_9[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_9 (TFOpLambda) (None, 64, 20, 24, 2 0           instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 64, 20, 24, 2 110656      tf.nn.leaky_relu_9[0][0]
# __________________________________________________________________________________________________
# instance_normalization_10 (Inst (None, 64, 20, 24, 2 128         conv3d_10[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_10 (TFOpLambda (None, 64, 20, 24, 2 0           instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf.identity_3 (TFOpLambda)      (None, 64, 20, 24, 2 0           tf.nn.leaky_relu_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 64, 20, 24, 2 110656      tf.identity_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_11 (Inst (None, 64, 20, 24, 2 128         conv3d_11[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_11 (TFOpLambda (None, 64, 20, 24, 2 0           instance_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 64, 20, 24, 2 0           tf.nn.leaky_relu_9[0][0]
#                                                                  tf.nn.leaky_relu_11[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 128, 10, 12,  221312      tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_12 (Inst (None, 128, 10, 12,  256         conv3d_12[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_12 (TFOpLambda (None, 128, 10, 12,  0           instance_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 128, 10, 12,  442496      tf.nn.leaky_relu_12[0][0]
# __________________________________________________________________________________________________
# instance_normalization_13 (Inst (None, 128, 10, 12,  256         conv3d_13[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_13 (TFOpLambda (None, 128, 10, 12,  0           instance_normalization_13[0][0]
# __________________________________________________________________________________________________
# tf.identity_4 (TFOpLambda)      (None, 128, 10, 12,  0           tf.nn.leaky_relu_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 128, 10, 12,  442496      tf.identity_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_14 (Inst (None, 128, 10, 12,  256         conv3d_14[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_14 (TFOpLambda (None, 128, 10, 12,  0           instance_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 128, 10, 12,  0           tf.nn.leaky_relu_12[0][0]
#                                                                  tf.nn.leaky_relu_14[0][0]
# __________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)    (None, 128, 20, 24,  0           tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 64, 20, 24, 2 221248      up_sampling3d[0][0]
# __________________________________________________________________________________________________
# instance_normalization_15 (Inst (None, 64, 20, 24, 2 128         conv3d_15[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_15 (TFOpLambda (None, 64, 20, 24, 2 0           instance_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 20, 24,  0           tf.__operators__.add_3[0][0]
#                                                                  tf.nn.leaky_relu_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 64, 20, 24, 2 221248      concatenate[0][0]
# __________________________________________________________________________________________________
# instance_normalization_16 (Inst (None, 64, 20, 24, 2 128         conv3d_16[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_16 (TFOpLambda (None, 64, 20, 24, 2 0           instance_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 64, 20, 24, 2 4160        tf.nn.leaky_relu_16[0][0]
# __________________________________________________________________________________________________
# instance_normalization_17 (Inst (None, 64, 20, 24, 2 128         conv3d_17[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_17 (TFOpLambda (None, 64, 20, 24, 2 0           instance_normalization_17[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 64, 40, 48, 4 0           tf.nn.leaky_relu_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 32, 40, 48, 4 55328       up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_18 (Inst (None, 32, 40, 48, 4 64          conv3d_18[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_18 (TFOpLambda (None, 32, 40, 48, 4 0           instance_normalization_18[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 40, 48, 4 0           tf.__operators__.add_2[0][0]
#                                                                  tf.nn.leaky_relu_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 32, 40, 48, 4 55328       concatenate_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_19 (Inst (None, 32, 40, 48, 4 64          conv3d_19[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_19 (TFOpLambda (None, 32, 40, 48, 4 0           instance_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 32, 40, 48, 4 1056        tf.nn.leaky_relu_19[0][0]
# __________________________________________________________________________________________________
# instance_normalization_20 (Inst (None, 32, 40, 48, 4 64          conv3d_20[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_20 (TFOpLambda (None, 32, 40, 48, 4 0           instance_normalization_20[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 32, 80, 96, 8 0           tf.nn.leaky_relu_20[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 16, 80, 96, 8 13840       up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_22 (Inst (None, 16, 80, 96, 8 32          conv3d_22[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_22 (TFOpLambda (None, 16, 80, 96, 8 0           instance_normalization_22[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 80, 96, 8 0           tf.__operators__.add_1[0][0]
#                                                                  tf.nn.leaky_relu_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 16, 80, 96, 8 13840       concatenate_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_23 (Inst (None, 16, 80, 96, 8 32          conv3d_23[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_23 (TFOpLambda (None, 16, 80, 96, 8 0           instance_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 16, 80, 96, 8 272         tf.nn.leaky_relu_23[0][0]
# __________________________________________________________________________________________________
# instance_normalization_24 (Inst (None, 16, 80, 96, 8 32          conv3d_24[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_24 (TFOpLambda (None, 16, 80, 96, 8 0           instance_normalization_24[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 16, 160, 192, 0           tf.nn.leaky_relu_24[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 8, 160, 192,  3464        up_sampling3d_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_26 (Inst (None, 8, 160, 192,  16          conv3d_26[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_26 (TFOpLambda (None, 8, 160, 192,  0           instance_normalization_26[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 160, 192, 0           tf.__operators__.add[0][0]
#                                                                  tf.nn.leaky_relu_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 8, 160, 192,  3464        concatenate_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_27 (Inst (None, 8, 160, 192,  16          conv3d_27[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_27 (TFOpLambda (None, 8, 160, 192,  0           instance_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 3, 40, 48, 40 99          tf.nn.leaky_relu_20[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 8, 160, 192,  72          tf.nn.leaky_relu_27[0][0]
# __________________________________________________________________________________________________
# instance_normalization_21 (Inst (None, 3, 40, 48, 40 6           conv3d_21[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 3, 80, 96, 80 51          tf.nn.leaky_relu_24[0][0]
# __________________________________________________________________________________________________
# instance_normalization_28 (Inst (None, 8, 160, 192,  16          conv3d_28[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_21 (TFOpLambda (None, 3, 40, 48, 40 0           instance_normalization_21[0][0]
# __________________________________________________________________________________________________
# instance_normalization_25 (Inst (None, 3, 80, 96, 80 6           conv3d_25[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_28 (TFOpLambda (None, 8, 160, 192,  0           instance_normalization_28[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 3, 80, 96, 80 0           tf.nn.leaky_relu_21[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_25 (TFOpLambda (None, 3, 80, 96, 80 0           instance_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 3, 160, 192,  27          tf.nn.leaky_relu_28[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 3, 80, 96, 80 0           up_sampling3d_4[0][0]
#                                                                  tf.nn.leaky_relu_25[0][0]
# __________________________________________________________________________________________________
# instance_normalization_29 (Inst (None, 3, 160, 192,  6           conv3d_29[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_5 (UpSampling3D)  (None, 3, 160, 192,  0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_29 (TFOpLambda (None, 3, 160, 192,  0           instance_normalization_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 3, 160, 192,  0           up_sampling3d_5[0][0]
#                                                                  tf.nn.leaky_relu_29[0][0]
# __________________________________________________________________________________________________
# activation_block (Activation)   (None, 3, 160, 192,  0           tf.__operators__.add_6[0][0]
# ==================================================================================================
# Total params: 2,069,587
# Trainable params: 2,069,587
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.config.list_physical_devices('GPU')

# %% [markdown]
# ### Save training history and predictions for 1 prediction:

# %% [markdown]
# ### 2 predictions compilation (all data):

# %%
model = Model(inputs=inputs, outputs=[activation_block,tumortype_block])
model.load_weights("./weights/model_1_weights.h5", by_name=True) # the by_name=True allows you to use a different architecture and bring in the weights from the matching layers 

model.compile(optimizer="adam", 
              loss={'activation_block': weighted_dice_coefficient_loss, 'tumortype_block': 'binary_crossentropy'}, 
              loss_weights={'activation_block': 1., 'tumortype_block': 0.2},
             metrics={'activation_block': ['accuracy',weighted_dice_coefficient, dice_coefficient], 'tumortype_block': ['accuracy']})


model.summary(line_length=150) # add the parameter that allows me to show everything instead of cutting it off
# Out:
# Model: "model_1"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_1 (InputLayer)                             [(None, 4, 160, 192, 160)]       0
# ______________________________________________________________________________________________________________________________________________________
# conv3d (Conv3D)                                  (None, 8, 160, 192, 160)         872               input_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization (InstanceNormalization)   (None, 8, 160, 192, 160)         16                conv3d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu (TFOpLambda)                    (None, 8, 160, 192, 160)         0                 instance_normalization[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_1 (Conv3D)                                (None, 8, 160, 192, 160)         1736              tf.nn.leaky_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_1 (InstanceNormalization) (None, 8, 160, 192, 160)         16                conv3d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_1 (TFOpLambda)                  (None, 8, 160, 192, 160)         0                 instance_normalization_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity (TFOpLambda)                         (None, 8, 160, 192, 160)         0                 tf.nn.leaky_relu_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_2 (Conv3D)                                (None, 8, 160, 192, 160)         1736              tf.identity[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_2 (InstanceNormalization) (None, 8, 160, 192, 160)         16                conv3d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_2 (TFOpLambda)                  (None, 8, 160, 192, 160)         0                 instance_normalization_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambda)                (None, 8, 160, 192, 160)         0                 tf.nn.leaky_relu[0][0]
#                                                                                                     tf.nn.leaky_relu_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_3 (Conv3D)                                (None, 16, 80, 96, 80)           3472              tf.__operators__.add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_3 (InstanceNormalization) (None, 16, 80, 96, 80)           32                conv3d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_3 (TFOpLambda)                  (None, 16, 80, 96, 80)           0                 instance_normalization_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_4 (Conv3D)                                (None, 16, 80, 96, 80)           6928              tf.nn.leaky_relu_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_4 (InstanceNormalization) (None, 16, 80, 96, 80)           32                conv3d_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_4 (TFOpLambda)                  (None, 16, 80, 96, 80)           0                 instance_normalization_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_1 (TFOpLambda)                       (None, 16, 80, 96, 80)           0                 tf.nn.leaky_relu_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_5 (Conv3D)                                (None, 16, 80, 96, 80)           6928              tf.identity_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_5 (InstanceNormalization) (None, 16, 80, 96, 80)           32                conv3d_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_5 (TFOpLambda)                  (None, 16, 80, 96, 80)           0                 instance_normalization_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLambda)              (None, 16, 80, 96, 80)           0                 tf.nn.leaky_relu_3[0][0]
#                                                                                                     tf.nn.leaky_relu_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_6 (Conv3D)                                (None, 32, 40, 48, 40)           13856             tf.__operators__.add_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_6 (InstanceNormalization) (None, 32, 40, 48, 40)           64                conv3d_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_6 (TFOpLambda)                  (None, 32, 40, 48, 40)           0                 instance_normalization_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_7 (Conv3D)                                (None, 32, 40, 48, 40)           27680             tf.nn.leaky_relu_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_7 (InstanceNormalization) (None, 32, 40, 48, 40)           64                conv3d_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_7 (TFOpLambda)                  (None, 32, 40, 48, 40)           0                 instance_normalization_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_2 (TFOpLambda)                       (None, 32, 40, 48, 40)           0                 tf.nn.leaky_relu_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_8 (Conv3D)                                (None, 32, 40, 48, 40)           27680             tf.identity_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_8 (InstanceNormalization) (None, 32, 40, 48, 40)           64                conv3d_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_8 (TFOpLambda)                  (None, 32, 40, 48, 40)           0                 instance_normalization_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLambda)              (None, 32, 40, 48, 40)           0                 tf.nn.leaky_relu_6[0][0]
#                                                                                                     tf.nn.leaky_relu_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_9 (Conv3D)                                (None, 64, 20, 24, 20)           55360             tf.__operators__.add_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_9 (InstanceNormalization) (None, 64, 20, 24, 20)           128               conv3d_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_9 (TFOpLambda)                  (None, 64, 20, 24, 20)           0                 instance_normalization_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_10 (Conv3D)                               (None, 64, 20, 24, 20)           110656            tf.nn.leaky_relu_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_10 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_10 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_3 (TFOpLambda)                       (None, 64, 20, 24, 20)           0                 tf.nn.leaky_relu_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_11 (Conv3D)                               (None, 64, 20, 24, 20)           110656            tf.identity_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_11 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_11 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLambda)              (None, 64, 20, 24, 20)           0                 tf.nn.leaky_relu_9[0][0]
#                                                                                                     tf.nn.leaky_relu_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_12 (Conv3D)                               (None, 128, 10, 12, 10)          221312            tf.__operators__.add_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_12 (InstanceNormalization (None, 128, 10, 12, 10)          256               conv3d_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_12 (TFOpLambda)                 (None, 128, 10, 12, 10)          0                 instance_normalization_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_13 (Conv3D)                               (None, 128, 10, 12, 10)          442496            tf.nn.leaky_relu_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_13 (InstanceNormalization (None, 128, 10, 12, 10)          256               conv3d_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_13 (TFOpLambda)                 (None, 128, 10, 12, 10)          0                 instance_normalization_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_4 (TFOpLambda)                       (None, 128, 10, 12, 10)          0                 tf.nn.leaky_relu_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_14 (Conv3D)                               (None, 128, 10, 12, 10)          442496            tf.identity_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_14 (InstanceNormalization (None, 128, 10, 12, 10)          256               conv3d_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_14 (TFOpLambda)                 (None, 128, 10, 12, 10)          0                 instance_normalization_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLambda)              (None, 128, 10, 12, 10)          0                 tf.nn.leaky_relu_12[0][0]
#                                                                                                     tf.nn.leaky_relu_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)                     (None, 128, 20, 24, 20)          0                 tf.__operators__.add_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_15 (Conv3D)                               (None, 64, 20, 24, 20)           221248            up_sampling3d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_15 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_15 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate (Concatenate)                        (None, 128, 20, 24, 20)          0                 tf.__operators__.add_3[0][0]
#                                                                                                     tf.nn.leaky_relu_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_16 (Conv3D)                               (None, 64, 20, 24, 20)           221248            concatenate[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_16 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_16 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_17 (Conv3D)                               (None, 64, 20, 24, 20)           4160              tf.nn.leaky_relu_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_17 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_17 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)                   (None, 64, 40, 48, 40)           0                 tf.nn.leaky_relu_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_18 (Conv3D)                               (None, 32, 40, 48, 40)           55328             up_sampling3d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_18 (InstanceNormalization (None, 32, 40, 48, 40)           64                conv3d_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_18 (TFOpLambda)                 (None, 32, 40, 48, 40)           0                 instance_normalization_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)                      (None, 64, 40, 48, 40)           0                 tf.__operators__.add_2[0][0]
#                                                                                                     tf.nn.leaky_relu_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_19 (Conv3D)                               (None, 32, 40, 48, 40)           55328             concatenate_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_19 (InstanceNormalization (None, 32, 40, 48, 40)           64                conv3d_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_19 (TFOpLambda)                 (None, 32, 40, 48, 40)           0                 instance_normalization_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_20 (Conv3D)                               (None, 32, 40, 48, 40)           1056              tf.nn.leaky_relu_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_20 (InstanceNormalization (None, 32, 40, 48, 40)           64                conv3d_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_20 (TFOpLambda)                 (None, 32, 40, 48, 40)           0                 instance_normalization_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)                   (None, 32, 80, 96, 80)           0                 tf.nn.leaky_relu_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_22 (Conv3D)                               (None, 16, 80, 96, 80)           13840             up_sampling3d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_22 (InstanceNormalization (None, 16, 80, 96, 80)           32                conv3d_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_22 (TFOpLambda)                 (None, 16, 80, 96, 80)           0                 instance_normalization_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_2 (Concatenate)                      (None, 32, 80, 96, 80)           0                 tf.__operators__.add_1[0][0]
#                                                                                                     tf.nn.leaky_relu_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_23 (Conv3D)                               (None, 16, 80, 96, 80)           13840             concatenate_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_23 (InstanceNormalization (None, 16, 80, 96, 80)           32                conv3d_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_23 (TFOpLambda)                 (None, 16, 80, 96, 80)           0                 instance_normalization_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_24 (Conv3D)                               (None, 16, 80, 96, 80)           272               tf.nn.leaky_relu_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_24 (InstanceNormalization (None, 16, 80, 96, 80)           32                conv3d_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_24 (TFOpLambda)                 (None, 16, 80, 96, 80)           0                 instance_normalization_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)                   (None, 16, 160, 192, 160)        0                 tf.nn.leaky_relu_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_26 (Conv3D)                               (None, 8, 160, 192, 160)         3464              up_sampling3d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_26 (InstanceNormalization (None, 8, 160, 192, 160)         16                conv3d_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_26 (TFOpLambda)                 (None, 8, 160, 192, 160)         0                 instance_normalization_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_3 (Concatenate)                      (None, 16, 160, 192, 160)        0                 tf.__operators__.add[0][0]
#                                                                                                     tf.nn.leaky_relu_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_27 (Conv3D)                               (None, 8, 160, 192, 160)         3464              concatenate_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_27 (InstanceNormalization (None, 8, 160, 192, 160)         16                conv3d_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_27 (TFOpLambda)                 (None, 8, 160, 192, 160)         0                 instance_normalization_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_21 (Conv3D)                               (None, 3, 40, 48, 40)            99                tf.nn.leaky_relu_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_28 (Conv3D)                               (None, 8, 160, 192, 160)         72                tf.nn.leaky_relu_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_21 (InstanceNormalization (None, 3, 40, 48, 40)            6                 conv3d_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_25 (Conv3D)                               (None, 3, 80, 96, 80)            51                tf.nn.leaky_relu_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_28 (InstanceNormalization (None, 8, 160, 192, 160)         16                conv3d_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_21 (TFOpLambda)                 (None, 3, 40, 48, 40)            0                 instance_normalization_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_25 (InstanceNormalization (None, 3, 80, 96, 80)            6                 conv3d_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_28 (TFOpLambda)                 (None, 8, 160, 192, 160)         0                 instance_normalization_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tumortype_conv_1 (Conv3D)                        (None, 128, 10, 12, 10)          442496            tf.__operators__.add_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)                   (None, 3, 80, 96, 80)            0                 tf.nn.leaky_relu_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_25 (TFOpLambda)                 (None, 3, 80, 96, 80)            0                 instance_normalization_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_29 (Conv3D)                               (None, 3, 160, 192, 160)         27                tf.nn.leaky_relu_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tumortype_conv_2 (Conv3D)                        (None, 128, 10, 12, 10)          442496            tumortype_conv_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLambda)              (None, 3, 80, 96, 80)            0                 up_sampling3d_4[0][0]
#                                                                                                     tf.nn.leaky_relu_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_29 (InstanceNormalization (None, 3, 160, 192, 160)         6                 conv3d_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_6 (TFOpLambda)                       (None, 128, 10, 12, 10)          0                 tumortype_conv_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_5 (UpSampling3D)                   (None, 3, 160, 192, 160)         0                 tf.__operators__.add_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_29 (TFOpLambda)                 (None, 3, 160, 192, 160)         0                 instance_normalization_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tumortype_conv_3 (Conv3D)                        (None, 128, 10, 12, 10)          442496            tf.identity_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLambda)              (None, 3, 160, 192, 160)         0                 up_sampling3d_5[0][0]
#                                                                                                     tf.nn.leaky_relu_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tumortype_GAP (GlobalAveragePooling3D)           (None, 128)                      0                 tumortype_conv_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_block (Activation)                    (None, 3, 160, 192, 160)         0                 tf.__operators__.add_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tumortype_block (Dense)                          (None, 1)                        129               tumortype_GAP[0][0]
# ======================================================================================================================================================
# Total params: 3,397,204
# Trainable params: 3,397,204
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Train the 2 prediction full data net:

# %%
model.load_weights('./weights/model_3_weights_new.h5')
model.save('model3_new.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b1d6b8c3814c> in <module>
# ----> 1 model.load_weights('./weights/model_3_weights_new.h5')
#       2 model.save('model3_new.h5')
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2299             f, self.layers, skip_mismatch=skip_mismatch)
#    2300       else:
# -> 2301         hdf5_format.load_weights_from_hdf5_group(f, self.layers)
#    2302
#    2303   def _updated_config(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\saving\hdf5_format.py in load_weights_from_hdf5_group(f, layers)
#     686   layer_names = filtered_layer_names
#     687   if len(layer_names) != len(filtered_layers):
# --> 688     raise ValueError('You are trying to load a weight file '
#     689                      'containing ' + str(len(layer_names)) +
#     690                      ' layers into a model with ' + str(len(filtered_layers)) +
#
# ValueError: You are trying to load a weight file containing 64 layers into a model with 60 layers.

# %%
params = {'dim': (160,192,160),
          'batch_size': 1,
          'n_classes': 3,
          'n_channels': 4,
          'shuffle': True}

# Generators
training_generator = DataGenerator(partition['train'], **params)
validation_generator = DataGenerator(partition['test'], **params)

# cb_1=keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=2, verbose=0, mode='auto')
cb_2=keras.callbacks.ModelCheckpoint(filepath="./weights/2pred_weights.{epoch:02d}-{val_loss:.2f}.hdf5", monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)

results = model.fit_generator(generator=training_generator,
                    validation_data=validation_generator,
                   epochs=100,
                   callbacks=[cb_2])

model.save_weights("./weights/model_2_weights.h5")
print("Saved model to disk")

# %% [markdown]
# ### Save training history and predictions for 2 predictions (all data):

# %%
history_2_pred = results.history
pickle.dump( history_2_pred, open( "./weights/history_2_pred.pkl", "wb" ) )

params = {'dim': (160,192,160),
          'batch_size': 1,
          'n_classes': 3,
          'n_channels': 4,
          'shuffle': False}

# Turned shuffle off so that we can match the values in the dictionary to the predictions. 
# This way we can compare the predictions side-by-side with the ground truth.

validation_generator = DataGenerator(partition['holdout'], **params)

predictions_2_pred = model.predict_generator(generator=validation_generator)

pickle.dump( predictions_2_pred, open( "./weights/predictions_2_pred.pkl", "wb" ) )

# %% [markdown]
# ### 3 predictions compilation (all data):

# %%
model = Model(inputs=inputs, outputs=[activation_block,survival_block])
model.load_weights("./weights/model_1_weights.h5", by_name=True)

model.compile(optimizer="adam", 
              loss={'activation_block': weighted_dice_coefficient_loss, 'survival_block': 'mean_squared_error'}, 
              loss_weights={'activation_block': 1., 'survival_block': 0.2,},
             metrics={'activation_block': ['accuracy',weighted_dice_coefficient, dice_coefficient], 'survival_block': ['accuracy', 'mae']})

model.summary(line_length=150) # add the parameter that allows me to show everything instead of cutting it off
# Out:
# Model: "model_1"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_1 (InputLayer)                             [(None, 4, 160, 192, 160)]       0
# ______________________________________________________________________________________________________________________________________________________
# conv3d (Conv3D)                                  (None, 8, 160, 192, 160)         872               input_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization (InstanceNormalization)   (None, 8, 160, 192, 160)         16                conv3d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu (TFOpLambda)                    (None, 8, 160, 192, 160)         0                 instance_normalization[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_1 (Conv3D)                                (None, 8, 160, 192, 160)         1736              tf.nn.leaky_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_1 (InstanceNormalization) (None, 8, 160, 192, 160)         16                conv3d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_1 (TFOpLambda)                  (None, 8, 160, 192, 160)         0                 instance_normalization_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity (TFOpLambda)                         (None, 8, 160, 192, 160)         0                 tf.nn.leaky_relu_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_2 (Conv3D)                                (None, 8, 160, 192, 160)         1736              tf.identity[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_2 (InstanceNormalization) (None, 8, 160, 192, 160)         16                conv3d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_2 (TFOpLambda)                  (None, 8, 160, 192, 160)         0                 instance_normalization_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambda)                (None, 8, 160, 192, 160)         0                 tf.nn.leaky_relu[0][0]
#                                                                                                     tf.nn.leaky_relu_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_3 (Conv3D)                                (None, 16, 80, 96, 80)           3472              tf.__operators__.add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_3 (InstanceNormalization) (None, 16, 80, 96, 80)           32                conv3d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_3 (TFOpLambda)                  (None, 16, 80, 96, 80)           0                 instance_normalization_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_4 (Conv3D)                                (None, 16, 80, 96, 80)           6928              tf.nn.leaky_relu_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_4 (InstanceNormalization) (None, 16, 80, 96, 80)           32                conv3d_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_4 (TFOpLambda)                  (None, 16, 80, 96, 80)           0                 instance_normalization_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_1 (TFOpLambda)                       (None, 16, 80, 96, 80)           0                 tf.nn.leaky_relu_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_5 (Conv3D)                                (None, 16, 80, 96, 80)           6928              tf.identity_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_5 (InstanceNormalization) (None, 16, 80, 96, 80)           32                conv3d_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_5 (TFOpLambda)                  (None, 16, 80, 96, 80)           0                 instance_normalization_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLambda)              (None, 16, 80, 96, 80)           0                 tf.nn.leaky_relu_3[0][0]
#                                                                                                     tf.nn.leaky_relu_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_6 (Conv3D)                                (None, 32, 40, 48, 40)           13856             tf.__operators__.add_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_6 (InstanceNormalization) (None, 32, 40, 48, 40)           64                conv3d_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_6 (TFOpLambda)                  (None, 32, 40, 48, 40)           0                 instance_normalization_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_7 (Conv3D)                                (None, 32, 40, 48, 40)           27680             tf.nn.leaky_relu_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_7 (InstanceNormalization) (None, 32, 40, 48, 40)           64                conv3d_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_7 (TFOpLambda)                  (None, 32, 40, 48, 40)           0                 instance_normalization_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_2 (TFOpLambda)                       (None, 32, 40, 48, 40)           0                 tf.nn.leaky_relu_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_8 (Conv3D)                                (None, 32, 40, 48, 40)           27680             tf.identity_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_8 (InstanceNormalization) (None, 32, 40, 48, 40)           64                conv3d_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_8 (TFOpLambda)                  (None, 32, 40, 48, 40)           0                 instance_normalization_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLambda)              (None, 32, 40, 48, 40)           0                 tf.nn.leaky_relu_6[0][0]
#                                                                                                     tf.nn.leaky_relu_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_9 (Conv3D)                                (None, 64, 20, 24, 20)           55360             tf.__operators__.add_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_9 (InstanceNormalization) (None, 64, 20, 24, 20)           128               conv3d_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_9 (TFOpLambda)                  (None, 64, 20, 24, 20)           0                 instance_normalization_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_10 (Conv3D)                               (None, 64, 20, 24, 20)           110656            tf.nn.leaky_relu_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_10 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_10 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_3 (TFOpLambda)                       (None, 64, 20, 24, 20)           0                 tf.nn.leaky_relu_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_11 (Conv3D)                               (None, 64, 20, 24, 20)           110656            tf.identity_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_11 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_11 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLambda)              (None, 64, 20, 24, 20)           0                 tf.nn.leaky_relu_9[0][0]
#                                                                                                     tf.nn.leaky_relu_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_12 (Conv3D)                               (None, 128, 10, 12, 10)          221312            tf.__operators__.add_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_12 (InstanceNormalization (None, 128, 10, 12, 10)          256               conv3d_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_12 (TFOpLambda)                 (None, 128, 10, 12, 10)          0                 instance_normalization_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_13 (Conv3D)                               (None, 128, 10, 12, 10)          442496            tf.nn.leaky_relu_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_13 (InstanceNormalization (None, 128, 10, 12, 10)          256               conv3d_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_13 (TFOpLambda)                 (None, 128, 10, 12, 10)          0                 instance_normalization_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_4 (TFOpLambda)                       (None, 128, 10, 12, 10)          0                 tf.nn.leaky_relu_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_14 (Conv3D)                               (None, 128, 10, 12, 10)          442496            tf.identity_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_14 (InstanceNormalization (None, 128, 10, 12, 10)          256               conv3d_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_14 (TFOpLambda)                 (None, 128, 10, 12, 10)          0                 instance_normalization_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLambda)              (None, 128, 10, 12, 10)          0                 tf.nn.leaky_relu_12[0][0]
#                                                                                                     tf.nn.leaky_relu_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)                     (None, 128, 20, 24, 20)          0                 tf.__operators__.add_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_15 (Conv3D)                               (None, 64, 20, 24, 20)           221248            up_sampling3d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_15 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_15 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate (Concatenate)                        (None, 128, 20, 24, 20)          0                 tf.__operators__.add_3[0][0]
#                                                                                                     tf.nn.leaky_relu_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_16 (Conv3D)                               (None, 64, 20, 24, 20)           221248            concatenate[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_16 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_16 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_17 (Conv3D)                               (None, 64, 20, 24, 20)           4160              tf.nn.leaky_relu_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_17 (InstanceNormalization (None, 64, 20, 24, 20)           128               conv3d_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_17 (TFOpLambda)                 (None, 64, 20, 24, 20)           0                 instance_normalization_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)                   (None, 64, 40, 48, 40)           0                 tf.nn.leaky_relu_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_18 (Conv3D)                               (None, 32, 40, 48, 40)           55328             up_sampling3d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_18 (InstanceNormalization (None, 32, 40, 48, 40)           64                conv3d_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_18 (TFOpLambda)                 (None, 32, 40, 48, 40)           0                 instance_normalization_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)                      (None, 64, 40, 48, 40)           0                 tf.__operators__.add_2[0][0]
#                                                                                                     tf.nn.leaky_relu_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_19 (Conv3D)                               (None, 32, 40, 48, 40)           55328             concatenate_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_19 (InstanceNormalization (None, 32, 40, 48, 40)           64                conv3d_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_19 (TFOpLambda)                 (None, 32, 40, 48, 40)           0                 instance_normalization_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_20 (Conv3D)                               (None, 32, 40, 48, 40)           1056              tf.nn.leaky_relu_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_20 (InstanceNormalization (None, 32, 40, 48, 40)           64                conv3d_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_20 (TFOpLambda)                 (None, 32, 40, 48, 40)           0                 instance_normalization_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)                   (None, 32, 80, 96, 80)           0                 tf.nn.leaky_relu_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_22 (Conv3D)                               (None, 16, 80, 96, 80)           13840             up_sampling3d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_22 (InstanceNormalization (None, 16, 80, 96, 80)           32                conv3d_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_22 (TFOpLambda)                 (None, 16, 80, 96, 80)           0                 instance_normalization_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_2 (Concatenate)                      (None, 32, 80, 96, 80)           0                 tf.__operators__.add_1[0][0]
#                                                                                                     tf.nn.leaky_relu_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_23 (Conv3D)                               (None, 16, 80, 96, 80)           13840             concatenate_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_23 (InstanceNormalization (None, 16, 80, 96, 80)           32                conv3d_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_23 (TFOpLambda)                 (None, 16, 80, 96, 80)           0                 instance_normalization_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_24 (Conv3D)                               (None, 16, 80, 96, 80)           272               tf.nn.leaky_relu_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_24 (InstanceNormalization (None, 16, 80, 96, 80)           32                conv3d_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_24 (TFOpLambda)                 (None, 16, 80, 96, 80)           0                 instance_normalization_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)                   (None, 16, 160, 192, 160)        0                 tf.nn.leaky_relu_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_26 (Conv3D)                               (None, 8, 160, 192, 160)         3464              up_sampling3d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_26 (InstanceNormalization (None, 8, 160, 192, 160)         16                conv3d_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_26 (TFOpLambda)                 (None, 8, 160, 192, 160)         0                 instance_normalization_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_3 (Concatenate)                      (None, 16, 160, 192, 160)        0                 tf.__operators__.add[0][0]
#                                                                                                     tf.nn.leaky_relu_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_27 (Conv3D)                               (None, 8, 160, 192, 160)         3464              concatenate_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_27 (InstanceNormalization (None, 8, 160, 192, 160)         16                conv3d_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_27 (TFOpLambda)                 (None, 8, 160, 192, 160)         0                 instance_normalization_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_21 (Conv3D)                               (None, 3, 40, 48, 40)            99                tf.nn.leaky_relu_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_28 (Conv3D)                               (None, 8, 160, 192, 160)         72                tf.nn.leaky_relu_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_21 (InstanceNormalization (None, 3, 40, 48, 40)            6                 conv3d_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_25 (Conv3D)                               (None, 3, 80, 96, 80)            51                tf.nn.leaky_relu_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_28 (InstanceNormalization (None, 8, 160, 192, 160)         16                conv3d_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_21 (TFOpLambda)                 (None, 3, 40, 48, 40)            0                 instance_normalization_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_25 (InstanceNormalization (None, 3, 80, 96, 80)            6                 conv3d_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_28 (TFOpLambda)                 (None, 8, 160, 192, 160)         0                 instance_normalization_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# survival_conv_1 (Conv3D)                         (None, 128, 10, 12, 10)          442496            tf.__operators__.add_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)                   (None, 3, 80, 96, 80)            0                 tf.nn.leaky_relu_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_25 (TFOpLambda)                 (None, 3, 80, 96, 80)            0                 instance_normalization_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3d_29 (Conv3D)                               (None, 3, 160, 192, 160)         27                tf.nn.leaky_relu_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# survival_conv_2 (Conv3D)                         (None, 128, 10, 12, 10)          442496            survival_conv_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLambda)              (None, 3, 80, 96, 80)            0                 up_sampling3d_4[0][0]
#                                                                                                     tf.nn.leaky_relu_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# instance_normalization_29 (InstanceNormalization (None, 3, 160, 192, 160)         6                 conv3d_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.identity_5 (TFOpLambda)                       (None, 128, 10, 12, 10)          0                 survival_conv_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# up_sampling3d_5 (UpSampling3D)                   (None, 3, 160, 192, 160)         0                 tf.__operators__.add_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.nn.leaky_relu_29 (TFOpLambda)                 (None, 3, 160, 192, 160)         0                 instance_normalization_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# survival_conv_3 (Conv3D)                         (None, 128, 10, 12, 10)          442496            tf.identity_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLambda)              (None, 3, 160, 192, 160)         0                 up_sampling3d_5[0][0]
#                                                                                                     tf.nn.leaky_relu_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# survival_GAP (GlobalAveragePooling3D)            (None, 128)                      0                 survival_conv_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_block (Activation)                    (None, 3, 160, 192, 160)         0                 tf.__operators__.add_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# survival_block (Dense)                           (None, 1)                        129               survival_GAP[0][0]
# ======================================================================================================================================================
# Total params: 3,397,204
# Trainable params: 3,397,204
# Non-trainable params: 0
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Train the 3 prediction subset data net:

# %%
model.load_weights('./weights/model_3_weights_new.h5')
model.save('model3_new.h5')

# %%
model.load_weights('./weights/model_3_weights.h5')
params = {'dim': (160,192,160),
          'batch_size': 1,
          'n_classes': 3,
          'n_channels': 4,
          'shuffle': False}

# Turned shuffle off so that we can match the values in the dictionary to the predictions. 
# This way we can compare the predictions side-by-side with the ground truth.

validation_generator = SubDataGenerator(["BraTS19_TMC_11964_1"], **params)

predictions_1_pred = model.predict_generator(generator=validation_generator)
# Out:
# C:\Users\HassanIslam\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
print(predictions_1_pred[1])
# Out:
# [[172.54855]]

# %%
params = {'dim': (160,192,160),
          'batch_size': 1,
          'n_classes': 3,
          'n_channels': 4,
          'shuffle': True}

# Generators
training_generator = SubDataGenerator(subpartition['train'], **params)
validation_generator = SubDataGenerator(subpartition['test'], **params)

# cb_1=keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=2, verbose=0, mode='auto')
cb_2=keras.callbacks.ModelCheckpoint(filepath="./weights/3pred_weights.{epoch:02d}-{val_loss:.2f}.hdf5", monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)

results = model.fit_generator(generator=training_generator,
                    validation_data=validation_generator,
                   epochs=100,
                   callbacks=[cb_2])

model.save_weights("./weights/model_3_weights_new.h5")
print("Saved model to disk")
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# C:\Users\HassanIslam\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 153/153 [==============================] - 543s 3s/step - loss: 34401.5671 - activation_block_loss: -0.6854 - survival_block_loss: 172011.2295 - activation_block_accuracy: 0.0410 - activation_block_weighted_dice_coefficient: 0.6854 - activation_block_dice_coefficient: 0.7641 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 306.0289 - val_loss: 29991.5547 - val_activation_block_loss: -0.7218 - val_survival_block_loss: 149961.3594 - val_activation_block_accuracy: 0.0400 - val_activation_block_weighted_dice_coefficient: 0.7218 - val_activation_block_dice_coefficient: 0.7707 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 292.1718
# Epoch 2/100
# 153/153 [==============================] - 473s 3s/step - loss: 19784.2161 - activation_block_loss: -0.7034 - survival_block_loss: 98924.6184 - activation_block_accuracy: 0.0277 - activation_block_weighted_dice_coefficient: 0.7034 - activation_block_dice_coefficient: 0.7553 - survival_block_accuracy: 7.3553e-04 - survival_block_mae: 227.6232 - val_loss: 29440.4688 - val_activation_block_loss: -0.6738 - val_survival_block_loss: 147205.7500 - val_activation_block_accuracy: 0.1185 - val_activation_block_weighted_dice_coefficient: 0.6738 - val_activation_block_dice_coefficient: 0.7192 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 280.4292
# Epoch 3/100
# 153/153 [==============================] - 476s 3s/step - loss: 27586.8400 - activation_block_loss: -0.6317 - survival_block_loss: 137937.3265 - activation_block_accuracy: 0.0799 - activation_block_weighted_dice_coefficient: 0.6317 - activation_block_dice_coefficient: 0.6937 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 268.6998 - val_loss: 33019.8555 - val_activation_block_loss: -0.6926 - val_survival_block_loss: 165102.7812 - val_activation_block_accuracy: 0.0968 - val_activation_block_weighted_dice_coefficient: 0.6926 - val_activation_block_dice_coefficient: 0.7384 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 270.1634
# Epoch 4/100
# 153/153 [==============================] - 477s 3s/step - loss: 22264.2943 - activation_block_loss: -0.7035 - survival_block_loss: 111324.9909 - activation_block_accuracy: 0.0538 - activation_block_weighted_dice_coefficient: 0.7035 - activation_block_dice_coefficient: 0.7368 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 248.6011 - val_loss: 44997.5039 - val_activation_block_loss: -0.6723 - val_survival_block_loss: 224990.9375 - val_activation_block_accuracy: 0.0525 - val_activation_block_weighted_dice_coefficient: 0.6723 - val_activation_block_dice_coefficient: 0.7140 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 320.1861
# Epoch 5/100
# 153/153 [==============================] - 477s 3s/step - loss: 38464.9915 - activation_block_loss: -0.6643 - survival_block_loss: 192328.2430 - activation_block_accuracy: 0.0926 - activation_block_weighted_dice_coefficient: 0.6643 - activation_block_dice_coefficient: 0.7178 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 320.2215 - val_loss: 30772.5645 - val_activation_block_loss: -0.6965 - val_survival_block_loss: 153866.2656 - val_activation_block_accuracy: 0.1473 - val_activation_block_weighted_dice_coefficient: 0.6965 - val_activation_block_dice_coefficient: 0.7453 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 304.3444
# Epoch 6/100
# 153/153 [==============================] - 477s 3s/step - loss: 25942.8333 - activation_block_loss: -0.7032 - survival_block_loss: 129717.6875 - activation_block_accuracy: 0.1015 - activation_block_weighted_dice_coefficient: 0.7032 - activation_block_dice_coefficient: 0.7452 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 254.9873 - val_loss: 31721.7012 - val_activation_block_loss: -0.6967 - val_survival_block_loss: 158611.9688 - val_activation_block_accuracy: 0.0582 - val_activation_block_weighted_dice_coefficient: 0.6967 - val_activation_block_dice_coefficient: 0.7385 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 278.5815
# Epoch 7/100
# 153/153 [==============================] - 478s 3s/step - loss: 16115.4915 - activation_block_loss: -0.6969 - survival_block_loss: 80580.9332 - activation_block_accuracy: 0.0826 - activation_block_weighted_dice_coefficient: 0.6969 - activation_block_dice_coefficient: 0.7414 - survival_block_accuracy: 0.0027 - survival_block_mae: 195.6561 - val_loss: 30134.2285 - val_activation_block_loss: -0.6878 - val_survival_block_loss: 150674.5469 - val_activation_block_accuracy: 0.0657 - val_activation_block_weighted_dice_coefficient: 0.6878 - val_activation_block_dice_coefficient: 0.7413 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 284.4533
# Epoch 8/100
# 153/153 [==============================] - 477s 3s/step - loss: 19400.0072 - activation_block_loss: -0.7013 - survival_block_loss: 97003.5355 - activation_block_accuracy: 0.0775 - activation_block_weighted_dice_coefficient: 0.7013 - activation_block_dice_coefficient: 0.7500 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 208.7196 - val_loss: 30977.3418 - val_activation_block_loss: -0.6848 - val_survival_block_loss: 154890.1406 - val_activation_block_accuracy: 0.1087 - val_activation_block_weighted_dice_coefficient: 0.6848 - val_activation_block_dice_coefficient: 0.7267 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 304.8393
# Epoch 9/100
# 153/153 [==============================] - 479s 3s/step - loss: 22803.0930 - activation_block_loss: -0.6477 - survival_block_loss: 114018.6901 - activation_block_accuracy: 0.0758 - activation_block_weighted_dice_coefficient: 0.6477 - activation_block_dice_coefficient: 0.6915 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 240.8499 - val_loss: 33032.0742 - val_activation_block_loss: -0.6758 - val_survival_block_loss: 165163.7656 - val_activation_block_accuracy: 0.0872 - val_activation_block_weighted_dice_coefficient: 0.6758 - val_activation_block_dice_coefficient: 0.7164 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 280.7601
# Epoch 10/100
# 153/153 [==============================] - 478s 3s/step - loss: 23900.5872 - activation_block_loss: -0.6750 - survival_block_loss: 119506.3162 - activation_block_accuracy: 0.1099 - activation_block_weighted_dice_coefficient: 0.6750 - activation_block_dice_coefficient: 0.7262 - survival_block_accuracy: 0.0101 - survival_block_mae: 228.0576 - val_loss: 35644.1328 - val_activation_block_loss: -0.6430 - val_survival_block_loss: 178223.9219 - val_activation_block_accuracy: 0.0425 - val_activation_block_weighted_dice_coefficient: 0.6430 - val_activation_block_dice_coefficient: 0.6944 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 305.5773
# Epoch 11/100
# 153/153 [==============================] - 478s 3s/step - loss: 19835.7251 - activation_block_loss: -0.6699 - survival_block_loss: 99181.9702 - activation_block_accuracy: 0.0575 - activation_block_weighted_dice_coefficient: 0.6699 - activation_block_dice_coefficient: 0.7099 - survival_block_accuracy: 0.0497 - survival_block_mae: 228.1128 - val_loss: 55394.2930 - val_activation_block_loss: -0.6729 - val_survival_block_loss: 276974.8125 - val_activation_block_accuracy: 0.0471 - val_activation_block_weighted_dice_coefficient: 0.6729 - val_activation_block_dice_coefficient: 0.7126 - val_survival_block_accuracy: 0.1212 - val_survival_block_mae: 371.9926
# Epoch 12/100
# 153/153 [==============================] - 478s 3s/step - loss: 29162.6574 - activation_block_loss: -0.6664 - survival_block_loss: 145816.6106 - activation_block_accuracy: 0.0541 - activation_block_weighted_dice_coefficient: 0.6664 - activation_block_dice_coefficient: 0.7097 - survival_block_accuracy: 0.0000e+00 - survival_block_mae: 269.8933 - val_loss: 34659.2031 - val_activation_block_loss: -0.6798 - val_survival_block_loss: 173299.4062 - val_activation_block_accuracy: 0.0694 - val_activation_block_weighted_dice_coefficient: 0.6798 - val_activation_block_dice_coefficient: 0.7219 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 283.4562
# Epoch 13/100
# 153/153 [==============================] - 478s 3s/step - loss: 17537.3880 - activation_block_loss: -0.7023 - survival_block_loss: 87690.4483 - activation_block_accuracy: 0.0650 - activation_block_weighted_dice_coefficient: 0.7023 - activation_block_dice_coefficient: 0.7417 - survival_block_accuracy: 0.0045 - survival_block_mae: 218.6532 - val_loss: 30508.3262 - val_activation_block_loss: -0.6753 - val_survival_block_loss: 152544.9844 - val_activation_block_accuracy: 0.0845 - val_activation_block_weighted_dice_coefficient: 0.6753 - val_activation_block_dice_coefficient: 0.7214 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 274.6217
# Epoch 14/100
# 153/153 [==============================] - 478s 3s/step - loss: 19588.7064 - activation_block_loss: -0.6834 - survival_block_loss: 97946.9445 - activation_block_accuracy: 0.0776 - activation_block_weighted_dice_coefficient: 0.6834 - activation_block_dice_coefficient: 0.7185 - survival_block_accuracy: 0.0092 - survival_block_mae: 234.6931 - val_loss: 32148.7539 - val_activation_block_loss: -0.6880 - val_survival_block_loss: 160747.1875 - val_activation_block_accuracy: 0.0513 - val_activation_block_weighted_dice_coefficient: 0.6880 - val_activation_block_dice_coefficient: 0.7280 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 286.7899
# Epoch 15/100
# 153/153 [==============================] - 479s 3s/step - loss: 12719.9942 - activation_block_loss: -0.6922 - survival_block_loss: 63603.4308 - activation_block_accuracy: 0.0501 - activation_block_weighted_dice_coefficient: 0.6922 - activation_block_dice_coefficient: 0.7365 - survival_block_accuracy: 0.0047 - survival_block_mae: 186.0635 - val_loss: 34484.9766 - val_activation_block_loss: -0.6642 - val_survival_block_loss: 172428.2500 - val_activation_block_accuracy: 0.0603 - val_activation_block_weighted_dice_coefficient: 0.6642 - val_activation_block_dice_coefficient: 0.7187 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 311.6489
# Epoch 16/100
# 153/153 [==============================] - 480s 3s/step - loss: 17349.7932 - activation_block_loss: -0.7045 - survival_block_loss: 86752.5042 - activation_block_accuracy: 0.0367 - activation_block_weighted_dice_coefficient: 0.7045 - activation_block_dice_coefficient: 0.7430 - survival_block_accuracy: 0.0257 - survival_block_mae: 233.4973 - val_loss: 39296.4844 - val_activation_block_loss: -0.6652 - val_survival_block_loss: 196485.7500 - val_activation_block_accuracy: 0.0740 - val_activation_block_weighted_dice_coefficient: 0.6652 - val_activation_block_dice_coefficient: 0.7160 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 321.2133
# Epoch 17/100
# 153/153 [==============================] - 480s 3s/step - loss: 13263.7924 - activation_block_loss: -0.6731 - survival_block_loss: 66322.3346 - activation_block_accuracy: 0.0718 - activation_block_weighted_dice_coefficient: 0.6731 - activation_block_dice_coefficient: 0.7239 - survival_block_accuracy: 0.0218 - survival_block_mae: 196.9441 - val_loss: 34104.4180 - val_activation_block_loss: -0.6817 - val_survival_block_loss: 170525.5000 - val_activation_block_accuracy: 0.0946 - val_activation_block_weighted_dice_coefficient: 0.6817 - val_activation_block_dice_coefficient: 0.7340 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 313.1706
# Epoch 18/100
# 153/153 [==============================] - 480s 3s/step - loss: 12495.9825 - activation_block_loss: -0.7064 - survival_block_loss: 62483.4439 - activation_block_accuracy: 0.0694 - activation_block_weighted_dice_coefficient: 0.7064 - activation_block_dice_coefficient: 0.7376 - survival_block_accuracy: 0.0294 - survival_block_mae: 189.3387 - val_loss: 40954.2031 - val_activation_block_loss: -0.6620 - val_survival_block_loss: 204774.3281 - val_activation_block_accuracy: 0.0590 - val_activation_block_weighted_dice_coefficient: 0.6620 - val_activation_block_dice_coefficient: 0.7075 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 327.9311
# Epoch 19/100
# 153/153 [==============================] - 480s 3s/step - loss: 18123.3948 - activation_block_loss: -0.6916 - survival_block_loss: 90620.4241 - activation_block_accuracy: 0.0668 - activation_block_weighted_dice_coefficient: 0.6916 - activation_block_dice_coefficient: 0.7372 - survival_block_accuracy: 0.0439 - survival_block_mae: 215.4795 - val_loss: 41168.3125 - val_activation_block_loss: -0.6695 - val_survival_block_loss: 205844.8906 - val_activation_block_accuracy: 0.0498 - val_activation_block_weighted_dice_coefficient: 0.6695 - val_activation_block_dice_coefficient: 0.7140 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 316.4883
# Epoch 20/100
# 153/153 [==============================] - 480s 3s/step - loss: 12639.9068 - activation_block_loss: -0.6940 - survival_block_loss: 63203.0071 - activation_block_accuracy: 0.0383 - activation_block_weighted_dice_coefficient: 0.6940 - activation_block_dice_coefficient: 0.7307 - survival_block_accuracy: 0.0434 - survival_block_mae: 192.6989 - val_loss: 36479.5000 - val_activation_block_loss: -0.6960 - val_survival_block_loss: 182400.9844 - val_activation_block_accuracy: 0.0448 - val_activation_block_weighted_dice_coefficient: 0.6960 - val_activation_block_dice_coefficient: 0.7398 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 319.9395
# Epoch 21/100
# 153/153 [==============================] - 479s 3s/step - loss: 9073.3638 - activation_block_loss: -0.7006 - survival_block_loss: 45370.3254 - activation_block_accuracy: 0.0552 - activation_block_weighted_dice_coefficient: 0.7006 - activation_block_dice_coefficient: 0.7414 - survival_block_accuracy: 0.0429 - survival_block_mae: 163.2940 - val_loss: 33928.0898 - val_activation_block_loss: -0.6837 - val_survival_block_loss: 169643.8281 - val_activation_block_accuracy: 0.0834 - val_activation_block_weighted_dice_coefficient: 0.6837 - val_activation_block_dice_coefficient: 0.7345 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 308.2721
# Epoch 22/100
# 153/153 [==============================] - 480s 3s/step - loss: 13267.9994 - activation_block_loss: -0.6959 - survival_block_loss: 66343.4838 - activation_block_accuracy: 0.0873 - activation_block_weighted_dice_coefficient: 0.6959 - activation_block_dice_coefficient: 0.7363 - survival_block_accuracy: 0.0077 - survival_block_mae: 186.2768 - val_loss: 33158.5195 - val_activation_block_loss: -0.6888 - val_survival_block_loss: 165796.0156 - val_activation_block_accuracy: 0.0773 - val_activation_block_weighted_dice_coefficient: 0.6888 - val_activation_block_dice_coefficient: 0.7351 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 297.8064
# Epoch 23/100
# 153/153 [==============================] - 480s 3s/step - loss: 11587.7019 - activation_block_loss: -0.6963 - survival_block_loss: 57941.9868 - activation_block_accuracy: 0.0666 - activation_block_weighted_dice_coefficient: 0.6963 - activation_block_dice_coefficient: 0.7308 - survival_block_accuracy: 0.0130 - survival_block_mae: 188.8908 - val_loss: 40887.3438 - val_activation_block_loss: -0.6944 - val_survival_block_loss: 204440.1719 - val_activation_block_accuracy: 0.0712 - val_activation_block_weighted_dice_coefficient: 0.6944 - val_activation_block_dice_coefficient: 0.7413 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 320.1767
# Epoch 24/100
# 153/153 [==============================] - 480s 3s/step - loss: 6854.0486 - activation_block_loss: -0.7386 - survival_block_loss: 34273.9342 - activation_block_accuracy: 0.0806 - activation_block_weighted_dice_coefficient: 0.7386 - activation_block_dice_coefficient: 0.7789 - survival_block_accuracy: 0.0653 - survival_block_mae: 138.2377 - val_loss: 36416.4727 - val_activation_block_loss: -0.7032 - val_survival_block_loss: 182085.8438 - val_activation_block_accuracy: 0.0963 - val_activation_block_weighted_dice_coefficient: 0.7032 - val_activation_block_dice_coefficient: 0.7463 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 317.2116
# Epoch 25/100
# 153/153 [==============================] - 481s 3s/step - loss: 5176.1796 - activation_block_loss: -0.7068 - survival_block_loss: 25884.4300 - activation_block_accuracy: 0.1074 - activation_block_weighted_dice_coefficient: 0.7068 - activation_block_dice_coefficient: 0.7565 - survival_block_accuracy: 0.0384 - survival_block_mae: 128.0880 - val_loss: 41160.9922 - val_activation_block_loss: -0.6857 - val_survival_block_loss: 205808.3750 - val_activation_block_accuracy: 0.0324 - val_activation_block_weighted_dice_coefficient: 0.6857 - val_activation_block_dice_coefficient: 0.7371 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 343.5807
# Epoch 26/100
# 153/153 [==============================] - 480s 3s/step - loss: 3885.0844 - activation_block_loss: -0.7142 - survival_block_loss: 19428.9926 - activation_block_accuracy: 0.0660 - activation_block_weighted_dice_coefficient: 0.7142 - activation_block_dice_coefficient: 0.7568 - survival_block_accuracy: 0.0788 - survival_block_mae: 107.1145 - val_loss: 39224.5195 - val_activation_block_loss: -0.6976 - val_survival_block_loss: 196126.0156 - val_activation_block_accuracy: 0.1264 - val_activation_block_weighted_dice_coefficient: 0.6976 - val_activation_block_dice_coefficient: 0.7459 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 307.9911
# Epoch 27/100
# 153/153 [==============================] - 480s 3s/step - loss: 4767.8543 - activation_block_loss: -0.7486 - survival_block_loss: 23843.0139 - activation_block_accuracy: 0.0823 - activation_block_weighted_dice_coefficient: 0.7486 - activation_block_dice_coefficient: 0.7764 - survival_block_accuracy: 0.0413 - survival_block_mae: 115.6819 - val_loss: 36204.6914 - val_activation_block_loss: -0.6656 - val_survival_block_loss: 181026.7500 - val_activation_block_accuracy: 0.1468 - val_activation_block_weighted_dice_coefficient: 0.6656 - val_activation_block_dice_coefficient: 0.7215 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 319.8913
# Epoch 28/100
# 153/153 [==============================] - 480s 3s/step - loss: 3640.1670 - activation_block_loss: -0.7003 - survival_block_loss: 18204.3356 - activation_block_accuracy: 0.1077 - activation_block_weighted_dice_coefficient: 0.7003 - activation_block_dice_coefficient: 0.7389 - survival_block_accuracy: 0.0790 - survival_block_mae: 101.5808 - val_loss: 38990.9258 - val_activation_block_loss: -0.7062 - val_survival_block_loss: 194958.1250 - val_activation_block_accuracy: 0.1491 - val_activation_block_weighted_dice_coefficient: 0.7062 - val_activation_block_dice_coefficient: 0.7521 - val_survival_block_accuracy: 0.0606 - val_survival_block_mae: 321.7633
# Epoch 29/100
# 153/153 [==============================] - 480s 3s/step - loss: 3981.3995 - activation_block_loss: -0.7424 - survival_block_loss: 19910.7087 - activation_block_accuracy: 0.1181 - activation_block_weighted_dice_coefficient: 0.7424 - activation_block_dice_coefficient: 0.7762 - survival_block_accuracy: 0.1284 - survival_block_mae: 103.2680 - val_loss: 38563.6523 - val_activation_block_loss: -0.6819 - val_survival_block_loss: 192821.6719 - val_activation_block_accuracy: 0.1708 - val_activation_block_weighted_dice_coefficient: 0.6819 - val_activation_block_dice_coefficient: 0.7168 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 311.7174
# Epoch 30/100
# 153/153 [==============================] - 479s 3s/step - loss: 2658.7670 - activation_block_loss: -0.7236 - survival_block_loss: 13297.4493 - activation_block_accuracy: 0.1400 - activation_block_weighted_dice_coefficient: 0.7236 - activation_block_dice_coefficient: 0.7524 - survival_block_accuracy: 0.0379 - survival_block_mae: 86.8515 - val_loss: 41026.9414 - val_activation_block_loss: -0.7005 - val_survival_block_loss: 205138.2500 - val_activation_block_accuracy: 0.1014 - val_activation_block_weighted_dice_coefficient: 0.7005 - val_activation_block_dice_coefficient: 0.7437 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 332.3847
# Epoch 31/100
# 153/153 [==============================] - 480s 3s/step - loss: 3603.6778 - activation_block_loss: -0.7320 - survival_block_loss: 18022.0522 - activation_block_accuracy: 0.1090 - activation_block_weighted_dice_coefficient: 0.7320 - activation_block_dice_coefficient: 0.7770 - survival_block_accuracy: 0.0556 - survival_block_mae: 102.3062 - val_loss: 34561.4414 - val_activation_block_loss: -0.6852 - val_survival_block_loss: 172810.7031 - val_activation_block_accuracy: 0.1229 - val_activation_block_weighted_dice_coefficient: 0.6852 - val_activation_block_dice_coefficient: 0.7331 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 289.6046
# Epoch 32/100
# 153/153 [==============================] - 480s 3s/step - loss: 2487.6941 - activation_block_loss: -0.7276 - survival_block_loss: 12442.1095 - activation_block_accuracy: 0.0697 - activation_block_weighted_dice_coefficient: 0.7276 - activation_block_dice_coefficient: 0.7639 - survival_block_accuracy: 0.0682 - survival_block_mae: 85.0233 - val_loss: 41363.0000 - val_activation_block_loss: -0.7052 - val_survival_block_loss: 206818.4375 - val_activation_block_accuracy: 0.1465 - val_activation_block_weighted_dice_coefficient: 0.7052 - val_activation_block_dice_coefficient: 0.7510 - val_survival_block_accuracy: 0.0606 - val_survival_block_mae: 317.3453
# Epoch 33/100
# 153/153 [==============================] - 481s 3s/step - loss: 3567.6679 - activation_block_loss: -0.7250 - survival_block_loss: 17841.9655 - activation_block_accuracy: 0.1160 - activation_block_weighted_dice_coefficient: 0.7250 - activation_block_dice_coefficient: 0.7623 - survival_block_accuracy: 0.0195 - survival_block_mae: 110.6898 - val_loss: 37277.1016 - val_activation_block_loss: -0.7031 - val_survival_block_loss: 186389.0000 - val_activation_block_accuracy: 0.0827 - val_activation_block_weighted_dice_coefficient: 0.7031 - val_activation_block_dice_coefficient: 0.7498 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 320.4846
# Epoch 34/100
# 153/153 [==============================] - 480s 3s/step - loss: 2297.6704 - activation_block_loss: -0.7435 - survival_block_loss: 11492.0661 - activation_block_accuracy: 0.0879 - activation_block_weighted_dice_coefficient: 0.7435 - activation_block_dice_coefficient: 0.7810 - survival_block_accuracy: 0.0682 - survival_block_mae: 77.1682 - val_loss: 33193.4531 - val_activation_block_loss: -0.7021 - val_survival_block_loss: 165970.7500 - val_activation_block_accuracy: 0.0994 - val_activation_block_weighted_dice_coefficient: 0.7021 - val_activation_block_dice_coefficient: 0.7521 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 293.6323
# Epoch 35/100
# 153/153 [==============================] - 479s 3s/step - loss: 2541.8987 - activation_block_loss: -0.7315 - survival_block_loss: 12713.1505 - activation_block_accuracy: 0.0877 - activation_block_weighted_dice_coefficient: 0.7315 - activation_block_dice_coefficient: 0.7687 - survival_block_accuracy: 0.0315 - survival_block_mae: 90.5131 - val_loss: 36994.5117 - val_activation_block_loss: -0.6725 - val_survival_block_loss: 184975.8750 - val_activation_block_accuracy: 0.0910 - val_activation_block_weighted_dice_coefficient: 0.6725 - val_activation_block_dice_coefficient: 0.7191 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 336.4494
# Epoch 36/100
# 153/153 [==============================] - 479s 3s/step - loss: 7707.1515 - activation_block_loss: -0.7247 - survival_block_loss: 38539.3784 - activation_block_accuracy: 0.1024 - activation_block_weighted_dice_coefficient: 0.7247 - activation_block_dice_coefficient: 0.7646 - survival_block_accuracy: 0.0611 - survival_block_mae: 154.5282 - val_loss: 36548.1445 - val_activation_block_loss: -0.6748 - val_survival_block_loss: 182744.0781 - val_activation_block_accuracy: 0.1457 - val_activation_block_weighted_dice_coefficient: 0.6748 - val_activation_block_dice_coefficient: 0.7262 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 319.3031
# Epoch 37/100
# 153/153 [==============================] - 479s 3s/step - loss: 5397.1316 - activation_block_loss: -0.7219 - survival_block_loss: 26989.2681 - activation_block_accuracy: 0.0904 - activation_block_weighted_dice_coefficient: 0.7219 - activation_block_dice_coefficient: 0.7644 - survival_block_accuracy: 0.0436 - survival_block_mae: 121.0790 - val_loss: 41135.2734 - val_activation_block_loss: -0.6796 - val_survival_block_loss: 205679.7656 - val_activation_block_accuracy: 0.1014 - val_activation_block_weighted_dice_coefficient: 0.6796 - val_activation_block_dice_coefficient: 0.7399 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 327.6255
# Epoch 38/100
# 153/153 [==============================] - 479s 3s/step - loss: 1732.1620 - activation_block_loss: -0.7249 - survival_block_loss: 8664.4345 - activation_block_accuracy: 0.1011 - activation_block_weighted_dice_coefficient: 0.7249 - activation_block_dice_coefficient: 0.7693 - survival_block_accuracy: 0.1020 - survival_block_mae: 71.2698 - val_loss: 36395.7969 - val_activation_block_loss: -0.7024 - val_survival_block_loss: 181982.5156 - val_activation_block_accuracy: 0.1037 - val_activation_block_weighted_dice_coefficient: 0.7024 - val_activation_block_dice_coefficient: 0.7568 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 313.8225
# Epoch 39/100
# 153/153 [==============================] - 479s 3s/step - loss: 1309.7467 - activation_block_loss: -0.7483 - survival_block_loss: 6552.4748 - activation_block_accuracy: 0.0997 - activation_block_weighted_dice_coefficient: 0.7483 - activation_block_dice_coefficient: 0.7714 - survival_block_accuracy: 0.0684 - survival_block_mae: 64.3307 - val_loss: 36681.5820 - val_activation_block_loss: -0.6839 - val_survival_block_loss: 183411.3594 - val_activation_block_accuracy: 0.1260 - val_activation_block_weighted_dice_coefficient: 0.6839 - val_activation_block_dice_coefficient: 0.7430 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 312.4246
# Epoch 40/100
# 153/153 [==============================] - 479s 3s/step - loss: 2455.9921 - activation_block_loss: -0.7396 - survival_block_loss: 12283.6567 - activation_block_accuracy: 0.1077 - activation_block_weighted_dice_coefficient: 0.7396 - activation_block_dice_coefficient: 0.7799 - survival_block_accuracy: 0.0334 - survival_block_mae: 81.7423 - val_loss: 37484.0508 - val_activation_block_loss: -0.7034 - val_survival_block_loss: 187423.7812 - val_activation_block_accuracy: 0.1332 - val_activation_block_weighted_dice_coefficient: 0.7034 - val_activation_block_dice_coefficient: 0.7529 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 312.4848
# Epoch 41/100
# 153/153 [==============================] - 480s 3s/step - loss: 784.9751 - activation_block_loss: -0.7611 - survival_block_loss: 3928.6817 - activation_block_accuracy: 0.0949 - activation_block_weighted_dice_coefficient: 0.7611 - activation_block_dice_coefficient: 0.7905 - survival_block_accuracy: 0.0529 - survival_block_mae: 47.2150 - val_loss: 40445.2148 - val_activation_block_loss: -0.6984 - val_survival_block_loss: 202229.5938 - val_activation_block_accuracy: 0.0846 - val_activation_block_weighted_dice_coefficient: 0.6984 - val_activation_block_dice_coefficient: 0.7424 - val_survival_block_accuracy: 0.0909 - val_survival_block_mae: 326.5614
# Epoch 42/100
# 153/153 [==============================] - 480s 3s/step - loss: 1393.0966 - activation_block_loss: -0.7484 - survival_block_loss: 6969.2249 - activation_block_accuracy: 0.0767 - activation_block_weighted_dice_coefficient: 0.7484 - activation_block_dice_coefficient: 0.7767 - survival_block_accuracy: 0.0833 - survival_block_mae: 63.5056 - val_loss: 35929.4648 - val_activation_block_loss: -0.6879 - val_survival_block_loss: 179650.8438 - val_activation_block_accuracy: 0.0746 - val_activation_block_weighted_dice_coefficient: 0.6879 - val_activation_block_dice_coefficient: 0.7454 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 308.5270
# Epoch 43/100
# 153/153 [==============================] - 480s 3s/step - loss: 1224.6856 - activation_block_loss: -0.7436 - survival_block_loss: 6127.1456 - activation_block_accuracy: 0.0772 - activation_block_weighted_dice_coefficient: 0.7436 - activation_block_dice_coefficient: 0.7779 - survival_block_accuracy: 0.0707 - survival_block_mae: 60.8688 - val_loss: 38221.3945 - val_activation_block_loss: -0.6960 - val_survival_block_loss: 191110.4844 - val_activation_block_accuracy: 0.0978 - val_activation_block_weighted_dice_coefficient: 0.6960 - val_activation_block_dice_coefficient: 0.7400 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 329.7823
# Epoch 44/100
# 153/153 [==============================] - 479s 3s/step - loss: 1736.2525 - activation_block_loss: -0.7502 - survival_block_loss: 8685.0136 - activation_block_accuracy: 0.0752 - activation_block_weighted_dice_coefficient: 0.7502 - activation_block_dice_coefficient: 0.7801 - survival_block_accuracy: 0.0628 - survival_block_mae: 70.8750 - val_loss: 39843.3242 - val_activation_block_loss: -0.6892 - val_survival_block_loss: 199220.0938 - val_activation_block_accuracy: 0.0606 - val_activation_block_weighted_dice_coefficient: 0.6892 - val_activation_block_dice_coefficient: 0.7419 - val_survival_block_accuracy: 0.0606 - val_survival_block_mae: 327.4521
# Epoch 45/100
# 153/153 [==============================] - 480s 3s/step - loss: 1076.0912 - activation_block_loss: -0.7721 - survival_block_loss: 5384.3170 - activation_block_accuracy: 0.0717 - activation_block_weighted_dice_coefficient: 0.7721 - activation_block_dice_coefficient: 0.8065 - survival_block_accuracy: 0.0602 - survival_block_mae: 54.0706 - val_loss: 39670.0469 - val_activation_block_loss: -0.7026 - val_survival_block_loss: 198353.8125 - val_activation_block_accuracy: 0.1117 - val_activation_block_weighted_dice_coefficient: 0.7026 - val_activation_block_dice_coefficient: 0.7488 - val_survival_block_accuracy: 0.0606 - val_survival_block_mae: 324.8694
# Epoch 46/100
# 153/153 [==============================] - 479s 3s/step - loss: 2207.9177 - activation_block_loss: -0.7544 - survival_block_loss: 11043.3576 - activation_block_accuracy: 0.0738 - activation_block_weighted_dice_coefficient: 0.7544 - activation_block_dice_coefficient: 0.7910 - survival_block_accuracy: 0.0599 - survival_block_mae: 80.5866 - val_loss: 44974.5742 - val_activation_block_loss: -0.6871 - val_survival_block_loss: 224876.3281 - val_activation_block_accuracy: 0.0661 - val_activation_block_weighted_dice_coefficient: 0.6871 - val_activation_block_dice_coefficient: 0.7333 - val_survival_block_accuracy: 0.0606 - val_survival_block_mae: 351.7328
# Epoch 47/100
# 153/153 [==============================] - 479s 3s/step - loss: 2855.7820 - activation_block_loss: -0.7476 - survival_block_loss: 14282.6489 - activation_block_accuracy: 0.0793 - activation_block_weighted_dice_coefficient: 0.7476 - activation_block_dice_coefficient: 0.7770 - survival_block_accuracy: 0.0242 - survival_block_mae: 95.8618 - val_loss: 36588.9336 - val_activation_block_loss: -0.7022 - val_survival_block_loss: 182948.1719 - val_activation_block_accuracy: 0.0569 - val_activation_block_weighted_dice_coefficient: 0.7022 - val_activation_block_dice_coefficient: 0.7525 - val_survival_block_accuracy: 0.0758 - val_survival_block_mae: 311.2188
# Epoch 48/100
# 153/153 [==============================] - 480s 3s/step - loss: 2009.4840 - activation_block_loss: -0.7429 - survival_block_loss: 10051.1328 - activation_block_accuracy: 0.0669 - activation_block_weighted_dice_coefficient: 0.7429 - activation_block_dice_coefficient: 0.7735 - survival_block_accuracy: 0.0230 - survival_block_mae: 77.0130 - val_loss: 30714.7754 - val_activation_block_loss: -0.6917 - val_survival_block_loss: 153577.3438 - val_activation_block_accuracy: 0.1011 - val_activation_block_weighted_dice_coefficient: 0.6917 - val_activation_block_dice_coefficient: 0.7417 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 302.1423
# Epoch 49/100
# 153/153 [==============================] - 480s 3s/step - loss: 13724.8638 - activation_block_loss: -0.7384 - survival_block_loss: 68627.9988 - activation_block_accuracy: 0.0615 - activation_block_weighted_dice_coefficient: 0.7384 - activation_block_dice_coefficient: 0.7658 - survival_block_accuracy: 0.0330 - survival_block_mae: 199.1982 - val_loss: 41138.4492 - val_activation_block_loss: -0.6430 - val_survival_block_loss: 205695.4531 - val_activation_block_accuracy: 0.0447 - val_activation_block_weighted_dice_coefficient: 0.6430 - val_activation_block_dice_coefficient: 0.7037 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 311.4818
# Epoch 50/100
# 153/153 [==============================] - 480s 3s/step - loss: 5873.5555 - activation_block_loss: -0.7224 - survival_block_loss: 29371.3862 - activation_block_accuracy: 0.0361 - activation_block_weighted_dice_coefficient: 0.7224 - activation_block_dice_coefficient: 0.7593 - survival_block_accuracy: 0.0299 - survival_block_mae: 123.7872 - val_loss: 38736.1406 - val_activation_block_loss: -0.7021 - val_survival_block_loss: 193684.2031 - val_activation_block_accuracy: 0.0618 - val_activation_block_weighted_dice_coefficient: 0.7021 - val_activation_block_dice_coefficient: 0.7530 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 306.8019
# Epoch 51/100
# 153/153 [==============================] - 480s 3s/step - loss: 4812.6392 - activation_block_loss: -0.7480 - survival_block_loss: 24066.9386 - activation_block_accuracy: 0.0539 - activation_block_weighted_dice_coefficient: 0.7480 - activation_block_dice_coefficient: 0.7755 - survival_block_accuracy: 0.0300 - survival_block_mae: 115.0986 - val_loss: 38002.7578 - val_activation_block_loss: -0.6919 - val_survival_block_loss: 190017.2500 - val_activation_block_accuracy: 0.0614 - val_activation_block_weighted_dice_coefficient: 0.6919 - val_activation_block_dice_coefficient: 0.7393 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 319.1269
# Epoch 52/100
# 153/153 [==============================] - 480s 3s/step - loss: 1839.5584 - activation_block_loss: -0.7556 - survival_block_loss: 9201.5697 - activation_block_accuracy: 0.0629 - activation_block_weighted_dice_coefficient: 0.7556 - activation_block_dice_coefficient: 0.7885 - survival_block_accuracy: 0.0768 - survival_block_mae: 71.1325 - val_loss: 35697.1680 - val_activation_block_loss: -0.6989 - val_survival_block_loss: 178489.2969 - val_activation_block_accuracy: 0.0343 - val_activation_block_weighted_dice_coefficient: 0.6989 - val_activation_block_dice_coefficient: 0.7493 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 287.8155
# Epoch 53/100
# 153/153 [==============================] - 479s 3s/step - loss: 5499.0520 - activation_block_loss: -0.7349 - survival_block_loss: 27498.9354 - activation_block_accuracy: 0.0554 - activation_block_weighted_dice_coefficient: 0.7349 - activation_block_dice_coefficient: 0.7762 - survival_block_accuracy: 0.0225 - survival_block_mae: 121.3242 - val_loss: 38412.0039 - val_activation_block_loss: -0.6965 - val_survival_block_loss: 192063.5156 - val_activation_block_accuracy: 0.0504 - val_activation_block_weighted_dice_coefficient: 0.6965 - val_activation_block_dice_coefficient: 0.7397 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 323.3802
# Epoch 54/100
# 153/153 [==============================] - 480s 3s/step - loss: 5703.2056 - activation_block_loss: -0.7418 - survival_block_loss: 28519.7350 - activation_block_accuracy: 0.0579 - activation_block_weighted_dice_coefficient: 0.7418 - activation_block_dice_coefficient: 0.7708 - survival_block_accuracy: 0.0619 - survival_block_mae: 125.2372 - val_loss: 39662.4219 - val_activation_block_loss: -0.7082 - val_survival_block_loss: 198315.6875 - val_activation_block_accuracy: 0.0473 - val_activation_block_weighted_dice_coefficient: 0.7082 - val_activation_block_dice_coefficient: 0.7532 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 313.0836
# Epoch 55/100
# 153/153 [==============================] - 479s 3s/step - loss: 1837.8787 - activation_block_loss: -0.7495 - survival_block_loss: 9193.1415 - activation_block_accuracy: 0.0411 - activation_block_weighted_dice_coefficient: 0.7495 - activation_block_dice_coefficient: 0.7903 - survival_block_accuracy: 0.0344 - survival_block_mae: 69.4381 - val_loss: 33809.4883 - val_activation_block_loss: -0.6905 - val_survival_block_loss: 169050.8750 - val_activation_block_accuracy: 0.0502 - val_activation_block_weighted_dice_coefficient: 0.6905 - val_activation_block_dice_coefficient: 0.7436 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 300.9768
# Epoch 56/100
# 153/153 [==============================] - 480s 3s/step - loss: 561.3903 - activation_block_loss: -0.7598 - survival_block_loss: 2810.7508 - activation_block_accuracy: 0.0551 - activation_block_weighted_dice_coefficient: 0.7598 - activation_block_dice_coefficient: 0.7899 - survival_block_accuracy: 0.0419 - survival_block_mae: 40.1883 - val_loss: 38654.5664 - val_activation_block_loss: -0.7115 - val_survival_block_loss: 193276.3750 - val_activation_block_accuracy: 0.0623 - val_activation_block_weighted_dice_coefficient: 0.7115 - val_activation_block_dice_coefficient: 0.7585 - val_survival_block_accuracy: 0.0758 - val_survival_block_mae: 308.7323
# Epoch 57/100
# 153/153 [==============================] - 480s 3s/step - loss: 988.9227 - activation_block_loss: -0.7680 - survival_block_loss: 4948.4549 - activation_block_accuracy: 0.0605 - activation_block_weighted_dice_coefficient: 0.7680 - activation_block_dice_coefficient: 0.8004 - survival_block_accuracy: 0.0449 - survival_block_mae: 55.3257 - val_loss: 36683.0664 - val_activation_block_loss: -0.7000 - val_survival_block_loss: 183418.8125 - val_activation_block_accuracy: 0.0779 - val_activation_block_weighted_dice_coefficient: 0.7000 - val_activation_block_dice_coefficient: 0.7439 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 315.1693
# Epoch 58/100
# 153/153 [==============================] - 480s 3s/step - loss: 561.4354 - activation_block_loss: -0.7686 - survival_block_loss: 2811.0206 - activation_block_accuracy: 0.0846 - activation_block_weighted_dice_coefficient: 0.7686 - activation_block_dice_coefficient: 0.7977 - survival_block_accuracy: 0.0923 - survival_block_mae: 41.5766 - val_loss: 38194.0781 - val_activation_block_loss: -0.7040 - val_survival_block_loss: 190973.8906 - val_activation_block_accuracy: 0.0613 - val_activation_block_weighted_dice_coefficient: 0.7040 - val_activation_block_dice_coefficient: 0.7541 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 309.8651
# Epoch 59/100
# 153/153 [==============================] - 480s 3s/step - loss: 384.8472 - activation_block_loss: -0.7702 - survival_block_loss: 1928.0868 - activation_block_accuracy: 0.0654 - activation_block_weighted_dice_coefficient: 0.7702 - activation_block_dice_coefficient: 0.8049 - survival_block_accuracy: 0.0463 - survival_block_mae: 35.3019 - val_loss: 36185.9648 - val_activation_block_loss: -0.6987 - val_survival_block_loss: 180933.2812 - val_activation_block_accuracy: 0.0432 - val_activation_block_weighted_dice_coefficient: 0.6987 - val_activation_block_dice_coefficient: 0.7559 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 303.4676
# Epoch 60/100
# 153/153 [==============================] - 479s 3s/step - loss: 657.4444 - activation_block_loss: -0.7705 - survival_block_loss: 3291.0743 - activation_block_accuracy: 0.0532 - activation_block_weighted_dice_coefficient: 0.7705 - activation_block_dice_coefficient: 0.8040 - survival_block_accuracy: 0.0549 - survival_block_mae: 45.0307 - val_loss: 34946.1484 - val_activation_block_loss: -0.6949 - val_survival_block_loss: 174734.2344 - val_activation_block_accuracy: 0.0438 - val_activation_block_weighted_dice_coefficient: 0.6949 - val_activation_block_dice_coefficient: 0.7501 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 299.4287
# Epoch 61/100
# 153/153 [==============================] - 479s 3s/step - loss: 634.8561 - activation_block_loss: -0.7424 - survival_block_loss: 3177.9916 - activation_block_accuracy: 0.0389 - activation_block_weighted_dice_coefficient: 0.7424 - activation_block_dice_coefficient: 0.7872 - survival_block_accuracy: 0.0310 - survival_block_mae: 42.4507 - val_loss: 37283.5859 - val_activation_block_loss: -0.6945 - val_survival_block_loss: 186421.3438 - val_activation_block_accuracy: 0.0354 - val_activation_block_weighted_dice_coefficient: 0.6945 - val_activation_block_dice_coefficient: 0.7467 - val_survival_block_accuracy: 0.0606 - val_survival_block_mae: 310.3384
# Epoch 62/100
# 153/153 [==============================] - 479s 3s/step - loss: 586.3386 - activation_block_loss: -0.7485 - survival_block_loss: 2935.4358 - activation_block_accuracy: 0.0295 - activation_block_weighted_dice_coefficient: 0.7485 - activation_block_dice_coefficient: 0.7918 - survival_block_accuracy: 0.0522 - survival_block_mae: 40.8964 - val_loss: 33342.3516 - val_activation_block_loss: -0.6944 - val_survival_block_loss: 166715.2812 - val_activation_block_accuracy: 0.0159 - val_activation_block_weighted_dice_coefficient: 0.6944 - val_activation_block_dice_coefficient: 0.7478 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 303.5845
# Epoch 63/100
# 153/153 [==============================] - 479s 3s/step - loss: 536.5829 - activation_block_loss: -0.7751 - survival_block_loss: 2686.7903 - activation_block_accuracy: 0.0323 - activation_block_weighted_dice_coefficient: 0.7751 - activation_block_dice_coefficient: 0.8093 - survival_block_accuracy: 0.0321 - survival_block_mae: 42.5013 - val_loss: 35345.7109 - val_activation_block_loss: -0.6920 - val_survival_block_loss: 176732.0312 - val_activation_block_accuracy: 0.0392 - val_activation_block_weighted_dice_coefficient: 0.6920 - val_activation_block_dice_coefficient: 0.7474 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 295.2520
# Epoch 64/100
# 153/153 [==============================] - 480s 3s/step - loss: 533.5634 - activation_block_loss: -0.7697 - survival_block_loss: 2671.6661 - activation_block_accuracy: 0.0481 - activation_block_weighted_dice_coefficient: 0.7697 - activation_block_dice_coefficient: 0.7943 - survival_block_accuracy: 0.0328 - survival_block_mae: 40.4807 - val_loss: 37699.4531 - val_activation_block_loss: -0.6970 - val_survival_block_loss: 188500.7812 - val_activation_block_accuracy: 0.0380 - val_activation_block_weighted_dice_coefficient: 0.6970 - val_activation_block_dice_coefficient: 0.7441 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 313.5525
# Epoch 65/100
# 153/153 [==============================] - 480s 3s/step - loss: 1000.4634 - activation_block_loss: -0.7689 - survival_block_loss: 5006.1616 - activation_block_accuracy: 0.0420 - activation_block_weighted_dice_coefficient: 0.7689 - activation_block_dice_coefficient: 0.8035 - survival_block_accuracy: 0.0631 - survival_block_mae: 54.3641 - val_loss: 32733.4512 - val_activation_block_loss: -0.6996 - val_survival_block_loss: 163670.7656 - val_activation_block_accuracy: 0.0410 - val_activation_block_weighted_dice_coefficient: 0.6996 - val_activation_block_dice_coefficient: 0.7552 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 296.2906
# Epoch 66/100
# 153/153 [==============================] - 480s 3s/step - loss: 2599.0829 - activation_block_loss: -0.7620 - survival_block_loss: 12999.2246 - activation_block_accuracy: 0.0373 - activation_block_weighted_dice_coefficient: 0.7620 - activation_block_dice_coefficient: 0.7973 - survival_block_accuracy: 0.0913 - survival_block_mae: 86.0775 - val_loss: 32394.2051 - val_activation_block_loss: -0.7054 - val_survival_block_loss: 161974.5312 - val_activation_block_accuracy: 0.0222 - val_activation_block_weighted_dice_coefficient: 0.7054 - val_activation_block_dice_coefficient: 0.7524 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 301.4419
# Epoch 67/100
# 153/153 [==============================] - 480s 3s/step - loss: 4740.9068 - activation_block_loss: -0.7557 - survival_block_loss: 23708.3158 - activation_block_accuracy: 0.0226 - activation_block_weighted_dice_coefficient: 0.7557 - activation_block_dice_coefficient: 0.7886 - survival_block_accuracy: 0.0329 - survival_block_mae: 115.0781 - val_loss: 34207.7461 - val_activation_block_loss: -0.7054 - val_survival_block_loss: 171042.2812 - val_activation_block_accuracy: 0.0281 - val_activation_block_weighted_dice_coefficient: 0.7054 - val_activation_block_dice_coefficient: 0.7573 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 302.3851
# Epoch 68/100
# 153/153 [==============================] - 480s 3s/step - loss: 3626.0622 - activation_block_loss: -0.7661 - survival_block_loss: 18134.1451 - activation_block_accuracy: 0.0512 - activation_block_weighted_dice_coefficient: 0.7661 - activation_block_dice_coefficient: 0.8052 - survival_block_accuracy: 0.0518 - survival_block_mae: 103.4457 - val_loss: 34164.4062 - val_activation_block_loss: -0.6874 - val_survival_block_loss: 170825.4688 - val_activation_block_accuracy: 0.0526 - val_activation_block_weighted_dice_coefficient: 0.6874 - val_activation_block_dice_coefficient: 0.7350 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 301.6389
# Epoch 69/100
# 153/153 [==============================] - 480s 3s/step - loss: 2447.4476 - activation_block_loss: -0.7685 - survival_block_loss: 12241.0790 - activation_block_accuracy: 0.0589 - activation_block_weighted_dice_coefficient: 0.7685 - activation_block_dice_coefficient: 0.8077 - survival_block_accuracy: 0.0321 - survival_block_mae: 82.1732 - val_loss: 33629.7812 - val_activation_block_loss: -0.6977 - val_survival_block_loss: 168152.3750 - val_activation_block_accuracy: 0.0420 - val_activation_block_weighted_dice_coefficient: 0.6977 - val_activation_block_dice_coefficient: 0.7554 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 294.0352
# Epoch 70/100
# 153/153 [==============================] - 479s 3s/step - loss: 1247.4927 - activation_block_loss: -0.7925 - survival_block_loss: 6241.4255 - activation_block_accuracy: 0.0517 - activation_block_weighted_dice_coefficient: 0.7925 - activation_block_dice_coefficient: 0.8217 - survival_block_accuracy: 0.0490 - survival_block_mae: 61.7121 - val_loss: 35363.9570 - val_activation_block_loss: -0.7026 - val_survival_block_loss: 176823.2500 - val_activation_block_accuracy: 0.0200 - val_activation_block_weighted_dice_coefficient: 0.7026 - val_activation_block_dice_coefficient: 0.7538 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 305.1796
# Epoch 71/100
# 153/153 [==============================] - 479s 3s/step - loss: 1023.0753 - activation_block_loss: -0.7785 - survival_block_loss: 5119.2691 - activation_block_accuracy: 0.0420 - activation_block_weighted_dice_coefficient: 0.7785 - activation_block_dice_coefficient: 0.8144 - survival_block_accuracy: 0.0779 - survival_block_mae: 56.8891 - val_loss: 34791.6523 - val_activation_block_loss: -0.7083 - val_survival_block_loss: 173961.7969 - val_activation_block_accuracy: 0.0650 - val_activation_block_weighted_dice_coefficient: 0.7083 - val_activation_block_dice_coefficient: 0.7554 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 302.6785
# ...
# Epoch 78/100
# 153/153 [==============================] - 480s 3s/step - loss: 632.1705 - activation_block_loss: -0.7782 - survival_block_loss: 3164.7436 - activation_block_accuracy: 0.0280 - activation_block_weighted_dice_coefficient: 0.7782 - activation_block_dice_coefficient: 0.8085 - survival_block_accuracy: 0.0635 - survival_block_mae: 41.5601 - val_loss: 34183.6055 - val_activation_block_loss: -0.7047 - val_survival_block_loss: 170921.5156 - val_activation_block_accuracy: 0.0253 - val_activation_block_weighted_dice_coefficient: 0.7047 - val_activation_block_dice_coefficient: 0.7569 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 295.8505
# Epoch 79/100
# 153/153 [==============================] - 480s 3s/step - loss: 1487.9266 - activation_block_loss: -0.7867 - survival_block_loss: 7443.5674 - activation_block_accuracy: 0.0264 - activation_block_weighted_dice_coefficient: 0.7867 - activation_block_dice_coefficient: 0.8162 - survival_block_accuracy: 0.0385 - survival_block_mae: 68.8500 - val_loss: 37830.2422 - val_activation_block_loss: -0.7047 - val_survival_block_loss: 189154.7500 - val_activation_block_accuracy: 0.0219 - val_activation_block_weighted_dice_coefficient: 0.7047 - val_activation_block_dice_coefficient: 0.7633 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 326.2103
# Epoch 80/100
# 153/153 [==============================] - 480s 3s/step - loss: 4558.7683 - activation_block_loss: -0.7814 - survival_block_loss: 22797.7478 - activation_block_accuracy: 0.0387 - activation_block_weighted_dice_coefficient: 0.7814 - activation_block_dice_coefficient: 0.8093 - survival_block_accuracy: 0.0485 - survival_block_mae: 112.5778 - val_loss: 48175.6562 - val_activation_block_loss: -0.6517 - val_survival_block_loss: 240881.4844 - val_activation_block_accuracy: 0.0131 - val_activation_block_weighted_dice_coefficient: 0.6517 - val_activation_block_dice_coefficient: 0.7048 - val_survival_block_accuracy: 0.1061 - val_survival_block_mae: 368.4182
# Epoch 81/100
# 153/153 [==============================] - 480s 3s/step - loss: 13028.1041 - activation_block_loss: -0.6849 - survival_block_loss: 65143.9541 - activation_block_accuracy: 0.0294 - activation_block_weighted_dice_coefficient: 0.6849 - activation_block_dice_coefficient: 0.7371 - survival_block_accuracy: 0.0698 - survival_block_mae: 185.8620 - val_loss: 33169.5352 - val_activation_block_loss: -0.6784 - val_survival_block_loss: 165851.0312 - val_activation_block_accuracy: 0.0234 - val_activation_block_weighted_dice_coefficient: 0.6784 - val_activation_block_dice_coefficient: 0.7271 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 302.1591
# Epoch 82/100
# 153/153 [==============================] - 480s 3s/step - loss: 3417.2551 - activation_block_loss: -0.7507 - survival_block_loss: 17090.0305 - activation_block_accuracy: 0.0265 - activation_block_weighted_dice_coefficient: 0.7507 - activation_block_dice_coefficient: 0.7909 - survival_block_accuracy: 0.0475 - survival_block_mae: 101.2281 - val_loss: 34423.1289 - val_activation_block_loss: -0.6817 - val_survival_block_loss: 172119.0625 - val_activation_block_accuracy: 0.0329 - val_activation_block_weighted_dice_coefficient: 0.6817 - val_activation_block_dice_coefficient: 0.7398 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 312.1418
# Epoch 83/100
# 153/153 [==============================] - 480s 3s/step - loss: 1153.6249 - activation_block_loss: -0.7444 - survival_block_loss: 5771.8462 - activation_block_accuracy: 0.0588 - activation_block_weighted_dice_coefficient: 0.7444 - activation_block_dice_coefficient: 0.7835 - survival_block_accuracy: 0.0442 - survival_block_mae: 60.1253 - val_loss: 35288.0742 - val_activation_block_loss: -0.6975 - val_survival_block_loss: 176443.8594 - val_activation_block_accuracy: 0.0139 - val_activation_block_weighted_dice_coefficient: 0.6975 - val_activation_block_dice_coefficient: 0.7480 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 307.1019
# Epoch 84/100
# 153/153 [==============================] - 479s 3s/step - loss: 704.7588 - activation_block_loss: -0.7652 - survival_block_loss: 3527.6201 - activation_block_accuracy: 0.0274 - activation_block_weighted_dice_coefficient: 0.7652 - activation_block_dice_coefficient: 0.7966 - survival_block_accuracy: 0.0277 - survival_block_mae: 45.5244 - val_loss: 34390.2734 - val_activation_block_loss: -0.6952 - val_survival_block_loss: 171954.8906 - val_activation_block_accuracy: 0.0465 - val_activation_block_weighted_dice_coefficient: 0.6952 - val_activation_block_dice_coefficient: 0.7509 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 303.5877
# Epoch 85/100
# 153/153 [==============================] - 480s 3s/step - loss: 648.3411 - activation_block_loss: -0.7806 - survival_block_loss: 3245.6083 - activation_block_accuracy: 0.0451 - activation_block_weighted_dice_coefficient: 0.7806 - activation_block_dice_coefficient: 0.8107 - survival_block_accuracy: 0.0623 - survival_block_mae: 46.1031 - val_loss: 35533.2891 - val_activation_block_loss: -0.7061 - val_survival_block_loss: 177670.0000 - val_activation_block_accuracy: 0.0300 - val_activation_block_weighted_dice_coefficient: 0.7061 - val_activation_block_dice_coefficient: 0.7560 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 303.8124
# Epoch 86/100
# 153/153 [==============================] - 480s 3s/step - loss: 417.0247 - activation_block_loss: -0.7962 - survival_block_loss: 2089.1042 - activation_block_accuracy: 0.0421 - activation_block_weighted_dice_coefficient: 0.7962 - activation_block_dice_coefficient: 0.8294 - survival_block_accuracy: 0.0384 - survival_block_mae: 34.4519 - val_loss: 38192.8242 - val_activation_block_loss: -0.6959 - val_survival_block_loss: 190967.6250 - val_activation_block_accuracy: 0.0443 - val_activation_block_weighted_dice_coefficient: 0.6959 - val_activation_block_dice_coefficient: 0.7425 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 311.4070
# Epoch 87/100
# 153/153 [==============================] - 480s 3s/step - loss: 811.6271 - activation_block_loss: -0.7653 - survival_block_loss: 4061.9614 - activation_block_accuracy: 0.0394 - activation_block_weighted_dice_coefficient: 0.7653 - activation_block_dice_coefficient: 0.8072 - survival_block_accuracy: 0.0231 - survival_block_mae: 49.2475 - val_loss: 35893.3125 - val_activation_block_loss: -0.6970 - val_survival_block_loss: 179470.0312 - val_activation_block_accuracy: 0.0178 - val_activation_block_weighted_dice_coefficient: 0.6970 - val_activation_block_dice_coefficient: 0.7533 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 309.6084
# Epoch 88/100
# 153/153 [==============================] - 479s 3s/step - loss: 399.1334 - activation_block_loss: -0.7782 - survival_block_loss: 1999.5576 - activation_block_accuracy: 0.0280 - activation_block_weighted_dice_coefficient: 0.7782 - activation_block_dice_coefficient: 0.8143 - survival_block_accuracy: 0.0798 - survival_block_mae: 33.6759 - val_loss: 34752.5898 - val_activation_block_loss: -0.6957 - val_survival_block_loss: 173766.4062 - val_activation_block_accuracy: 0.0255 - val_activation_block_weighted_dice_coefficient: 0.6957 - val_activation_block_dice_coefficient: 0.7503 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 299.4770
# Epoch 89/100
# 153/153 [==============================] - 480s 3s/step - loss: 197.3677 - activation_block_loss: -0.7908 - survival_block_loss: 990.7922 - activation_block_accuracy: 0.0354 - activation_block_weighted_dice_coefficient: 0.7908 - activation_block_dice_coefficient: 0.8145 - survival_block_accuracy: 0.0410 - survival_block_mae: 25.8258 - val_loss: 34706.0586 - val_activation_block_loss: -0.7001 - val_survival_block_loss: 173533.7656 - val_activation_block_accuracy: 0.0340 - val_activation_block_weighted_dice_coefficient: 0.7001 - val_activation_block_dice_coefficient: 0.7602 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 302.1239
# Epoch 90/100
# 153/153 [==============================] - 480s 3s/step - loss: 184.1049 - activation_block_loss: -0.7832 - survival_block_loss: 924.4405 - activation_block_accuracy: 0.0358 - activation_block_weighted_dice_coefficient: 0.7832 - activation_block_dice_coefficient: 0.8117 - survival_block_accuracy: 0.0393 - survival_block_mae: 22.7804 - val_loss: 35673.7383 - val_activation_block_loss: -0.7027 - val_survival_block_loss: 178372.2344 - val_activation_block_accuracy: 0.0476 - val_activation_block_weighted_dice_coefficient: 0.7027 - val_activation_block_dice_coefficient: 0.7574 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 307.1491
# Epoch 91/100
# 153/153 [==============================] - 479s 3s/step - loss: 217.3449 - activation_block_loss: -0.8051 - survival_block_loss: 1090.7503 - activation_block_accuracy: 0.0443 - activation_block_weighted_dice_coefficient: 0.8051 - activation_block_dice_coefficient: 0.8353 - survival_block_accuracy: 0.0734 - survival_block_mae: 26.3528 - val_loss: 37711.6836 - val_activation_block_loss: -0.6968 - val_survival_block_loss: 188561.8906 - val_activation_block_accuracy: 0.0175 - val_activation_block_weighted_dice_coefficient: 0.6968 - val_activation_block_dice_coefficient: 0.7485 - val_survival_block_accuracy: 0.0455 - val_survival_block_mae: 314.3715
# Epoch 92/100
# 153/153 [==============================] - 479s 3s/step - loss: 654.0229 - activation_block_loss: -0.7860 - survival_block_loss: 3274.0452 - activation_block_accuracy: 0.0332 - activation_block_weighted_dice_coefficient: 0.7860 - activation_block_dice_coefficient: 0.8137 - survival_block_accuracy: 0.1141 - survival_block_mae: 41.4964 - val_loss: 37020.5273 - val_activation_block_loss: -0.6975 - val_survival_block_loss: 185106.0938 - val_activation_block_accuracy: 0.0204 - val_activation_block_weighted_dice_coefficient: 0.6975 - val_activation_block_dice_coefficient: 0.7501 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 311.2820
# Epoch 93/100
# 153/153 [==============================] - 480s 3s/step - loss: 945.8256 - activation_block_loss: -0.7849 - survival_block_loss: 4733.0533 - activation_block_accuracy: 0.0280 - activation_block_weighted_dice_coefficient: 0.7849 - activation_block_dice_coefficient: 0.8212 - survival_block_accuracy: 0.0775 - survival_block_mae: 51.8324 - val_loss: 34814.1094 - val_activation_block_loss: -0.7049 - val_survival_block_loss: 174074.0469 - val_activation_block_accuracy: 0.0376 - val_activation_block_weighted_dice_coefficient: 0.7049 - val_activation_block_dice_coefficient: 0.7586 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 303.5249
# Epoch 94/100
# 153/153 [==============================] - 479s 3s/step - loss: 1797.2779 - activation_block_loss: -0.7969 - survival_block_loss: 8990.3735 - activation_block_accuracy: 0.0394 - activation_block_weighted_dice_coefficient: 0.7969 - activation_block_dice_coefficient: 0.8315 - survival_block_accuracy: 0.0583 - survival_block_mae: 72.3046 - val_loss: 32037.1484 - val_activation_block_loss: -0.7048 - val_survival_block_loss: 160189.2344 - val_activation_block_accuracy: 0.0280 - val_activation_block_weighted_dice_coefficient: 0.7048 - val_activation_block_dice_coefficient: 0.7514 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 288.3181
# Epoch 95/100
# 153/153 [==============================] - 479s 3s/step - loss: 1856.7310 - activation_block_loss: -0.7943 - survival_block_loss: 9287.6270 - activation_block_accuracy: 0.0302 - activation_block_weighted_dice_coefficient: 0.7943 - activation_block_dice_coefficient: 0.8170 - survival_block_accuracy: 0.0334 - survival_block_mae: 77.0645 - val_loss: 34448.7109 - val_activation_block_loss: -0.7019 - val_survival_block_loss: 172247.0938 - val_activation_block_accuracy: 0.0222 - val_activation_block_weighted_dice_coefficient: 0.7019 - val_activation_block_dice_coefficient: 0.7572 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 302.6612
# Epoch 96/100
# 153/153 [==============================] - 480s 3s/step - loss: 1169.9217 - activation_block_loss: -0.7852 - survival_block_loss: 5853.5340 - activation_block_accuracy: 0.0242 - activation_block_weighted_dice_coefficient: 0.7852 - activation_block_dice_coefficient: 0.8170 - survival_block_accuracy: 0.0464 - survival_block_mae: 60.5891 - val_loss: 32502.5723 - val_activation_block_loss: -0.6924 - val_survival_block_loss: 162516.3125 - val_activation_block_accuracy: 0.0396 - val_activation_block_weighted_dice_coefficient: 0.6924 - val_activation_block_dice_coefficient: 0.7500 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 297.7841
# Epoch 97/100
# 153/153 [==============================] - 481s 3s/step - loss: 1216.5296 - activation_block_loss: -0.8063 - survival_block_loss: 6086.6788 - activation_block_accuracy: 0.0491 - activation_block_weighted_dice_coefficient: 0.8063 - activation_block_dice_coefficient: 0.8367 - survival_block_accuracy: 0.0520 - survival_block_mae: 61.9041 - val_loss: 36654.8359 - val_activation_block_loss: -0.6523 - val_survival_block_loss: 183277.4531 - val_activation_block_accuracy: 0.0508 - val_activation_block_weighted_dice_coefficient: 0.6523 - val_activation_block_dice_coefficient: 0.7021 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 313.4717
# Epoch 98/100
# 153/153 [==============================] - 480s 3s/step - loss: 575.4253 - activation_block_loss: -0.7741 - survival_block_loss: 2880.9971 - activation_block_accuracy: 0.0456 - activation_block_weighted_dice_coefficient: 0.7741 - activation_block_dice_coefficient: 0.8051 - survival_block_accuracy: 0.0740 - survival_block_mae: 43.0022 - val_loss: 36184.1211 - val_activation_block_loss: -0.7080 - val_survival_block_loss: 180924.2031 - val_activation_block_accuracy: 0.0540 - val_activation_block_weighted_dice_coefficient: 0.7080 - val_activation_block_dice_coefficient: 0.7589 - val_survival_block_accuracy: 0.0303 - val_survival_block_mae: 305.8561
# Epoch 99/100
# 153/153 [==============================] - 480s 3s/step - loss: 485.1346 - activation_block_loss: -0.7984 - survival_block_loss: 2429.6648 - activation_block_accuracy: 0.0571 - activation_block_weighted_dice_coefficient: 0.7984 - activation_block_dice_coefficient: 0.8271 - survival_block_accuracy: 0.0642 - survival_block_mae: 35.8873 - val_loss: 36087.6250 - val_activation_block_loss: -0.7045 - val_survival_block_loss: 180441.6406 - val_activation_block_accuracy: 0.0459 - val_activation_block_weighted_dice_coefficient: 0.7045 - val_activation_block_dice_coefficient: 0.7558 - val_survival_block_accuracy: 0.0152 - val_survival_block_mae: 305.3981
# Epoch 100/100
# 153/153 [==============================] - 479s 3s/step - loss: 626.0705 - activation_block_loss: -0.7962 - survival_block_loss: 3134.3335 - activation_block_accuracy: 0.0407 - activation_block_weighted_dice_coefficient: 0.7962 - activation_block_dice_coefficient: 0.8239 - survival_block_accuracy: 0.1100 - survival_block_mae: 43.9277 - val_loss: 33396.3945 - val_activation_block_loss: -0.7028 - val_survival_block_loss: 166985.5156 - val_activation_block_accuracy: 0.0414 - val_activation_block_weighted_dice_coefficient: 0.7028 - val_activation_block_dice_coefficient: 0.7571 - val_survival_block_accuracy: 0.0000e+00 - val_survival_block_mae: 297.1237
# Saved model to disk

# %% [markdown]
# ### Save training history and predictions for 3 predictions (subset of data with survival predictions):

# %%
history_3_pred = results.history
pickle.dump( history_3_pred, open( "./weights/history_3_pred.pkl", "wb" ) )

params = {'dim': (160,192,160),
          'batch_size': 1,
          'n_classes': 3,
          'n_channels': 4,
          'shuffle': False}

# Turned shuffle off so that we can match the values in the dictionary to the predictions. 
# This way we can compare the predictions side-by-side with the ground truth.

validation_generator = SubDataGenerator(subpartition['holdout'], **params)

predictions_3_pred = model.predict_generator(generator=validation_generator)

pickle.dump( predictions_3_pred, open( "./weights/predictions_3_pred.pkl", "wb" ) )

# %% [markdown]
# ### Validation set predictions for 2 predictions (all data):

# %%
# score = model.evaluate(x_test, y_test, verbose=0)

params = {'dim': (160,192,160),
          'batch_size': 1,
          'n_classes': 3,
          'n_channels': 4,
          'shuffle': False}

# Turned shuffle off so that we can match the values in the dictionary to the predictions. 
# This way we can compare the predictions side-by-side with the ground truth.

validation_generator = DataGenerator(partition['holdout'], **params)

prediction = model.predict_generator(generator=validation_generator)
# print('Test loss:', score[0])
# print('Test accuracy:', score[1])
prediction

# %% [markdown]
# ### Validation set predictions for 3 predictions (subset of data with survival predictions):

# %%
# score = model.evaluate(x_test, y_test, verbose=0)

params = {'dim': (160,192,160),
          'batch_size': 1,
          'n_classes': 3,
          'n_channels': 4,
          'shuffle': False}

# Turned shuffle off so that we can match the values in the dictionary to the predictions. 
# This way we can compare the predictions side-by-side with the ground truth.

validation_generator = SubDataGenerator(subpartition['holdout'], **params)

prediction = model.predict_generator(generator=validation_generator)
# print('Test loss:', score[0])
# print('Test accuracy:', score[1])
prediction

# %%
# sanity check on the predictions:
len(prediction)
prediction[0].shape # segmentation mask
prediction[1].shape # survival
prediction[2].shape # tumor type
# np.unique(prediction)

# %%
# len(completelist)
len(set.intersection(set(HGG_dir_list), set(completelist)))
len(set.intersection(set(LGG_dir_list), set(completelist)))

# %%
# for ID in partition['holdout']:
#     print(tumor_type_dict[ID])

for ID in partition['holdout']:
    print(tumor_type_dict[ID])

# %%
# ! mkdir to_categorical_try
# ! mkdir channel_split

# %%
# import pickle

# pickle.dump( partition, open( "./channel_split/partition.pkl", "wb" ) ) # this has the test/train ID matches

# # # access the test list:
# # testIDlist = partition['test']
# # testIDlist

# %%
# for i in range(len(prediction)):
#     pickle.dump( prediction[i], open( "./channel_split/prediction_"+str(i)+".pkl", "wb" ) )

# %%
# # https://keras.io/getting-started/faq/#how-can-i-save-a-keras-model
# # pickle.dump( model, open( "model.pkl", "wb" ) )
# model.save_weights('./channel_split/my_model_weights.h5')

# %%
import pickle

partition = pickle.load(open( "./channel_split/partition.pkl", "rb" ) ) # this has the test/train ID matches

# access the test list:
testIDlist = partition['test']
# testIDlist

# %% [markdown]
# ### Write images to .tif:

# %%
from tifffile import imsave
for i in range(len(prediction)):
    imarray = pickle.load(open( "./channel_split/prediction_"+str(i)+".pkl", "rb" ) )

    imarray[]
    imarray *= 255.0/imarray.max()
    print(np.unique())
    
    imsave("./channel_split/"+testIDlist[i]+"prediction.tif", imarray)

    # make ground truth 
    ID = testIDlist[i]
    img1 = './data/' + ID + '_flair.nii.gz'
    img2 = './data/' + ID + '_t1.nii.gz'
    img3 = './data/' + ID + '_t1ce.nii.gz'
    img4 = './data/' + ID + '_t2.nii.gz'
    img5 = './data/' + ID + '_seg.nii.gz'

    newimage = nib.concat_images([img1, img2, img3, img4, img5])
    cropped = crop_img(newimage)         
    img_array = np.array(cropped.dataobj)
    z = np.rollaxis(img_array, 3, 0)

    padded_image = np.zeros((5,160,192,160))
    padded_image[:z.shape[0],:z.shape[1],:z.shape[2],:z.shape[3]] = z

    a,b,c,d,seg_mask = np.split(padded_image, 5, axis=0)

    images = np.concatenate([a,b,c,d], axis=0)
    imsave("./channel_split/"+testIDlist[i]+"ground_truth.tif", images)

# %% [markdown]
# ### Testing:

# %%
import pickle
import numpy as np
import copy
import nibabel as nib

i = 0

imarray = pickle.load(open( "./channel_split/prediction_"+str(i)+".pkl", "rb" ) )
# threshold the channels (for prediction):
prediction_thresh = copy.deepcopy(imarray)
prediction_thresh[prediction_thresh < 0.5] = 0.
prediction_thresh[prediction_thresh >= 0.5] = 1.
prediction_thresh = prediction_thresh
print(np.unique(prediction_thresh))
prediction_thresh *= 255.0/prediction_thresh.max() # convert to 8-bit pixel values
prediction_thresh = prediction_thresh.astype(int)
print(np.unique(prediction_thresh))
print(prediction_thresh.shape)

ID = testIDlist[i]
img1 = './data/' + ID + '_flair.nii.gz'
flairimg = nib.load(img1)
flairimg = np.array(flairimg.dataobj)
flairimg = np.expand_dims(flairimg, axis=0)
flairimg = np.rollaxis(flairimg, 3, 0)
print(np.unique(flairimg))
flairimg = flairimg.astype(float)
flairimg *= 255.0/flairimg.max() # convert to 8-bit pixel values
flairimg = flairimg.astype(int)
print(np.unique(flairimg))
print(flairimg.shape)

# %% [markdown]
# ### Making ground truth .tiff files:
# - Testing:

# %%
import numpy as np
import copy
import nibabel as nib

from tifffile import imsave
from libtiff import TIFF

from skimage.io._plugins import freeimage_plugin as fi

# import javabridge
# import bioformats
# javabridge.start_vm(class_path=bioformats.JARS)

# your program goes here


# ID = testIDlist[i]
# for i in range(len(testIDlist)):
for i in range(2):

    print("current image:", i)

    ID = testIDlist[i]
    img1 = './data/' + ID + '_flair.nii.gz'
    img2 = './data/' + ID + '_t1.nii.gz'
    img3 = './data/' + ID + '_t1ce.nii.gz'
    img4 = './data/' + ID + '_t2.nii.gz'
    img5 = './data/' + ID + '_seg.nii.gz'

    newimage = nib.concat_images([img1, img2, img3, img4, img5])
    cropped = crop_img(newimage)
    img_array = np.array(cropped.dataobj)
    z = np.rollaxis(img_array, 3, 0)

    padded_image = np.zeros((5, 160, 192, 160))
    padded_image[:z.shape[0], :z.shape[1], :z.shape[2], :z.shape[3]] = z

    a, b, c, d, seg_mask = np.split(padded_image, 5, axis=0)

    images = np.concatenate([a, b, c, d], axis=0)

    # print("images shape:", images.shape, "images values:", np.unique(images.astype(int)))

    # split the channels:
    # seg_mask_1 = copy.deepcopy(seg_mask.astype(int))
    seg_mask_1 = np.zeros((1, 160, 192, 160))
    seg_mask_1[seg_mask.astype(int) > 0] = 1
    seg_mask_2 = np.zeros((1, 160, 192, 160))
    seg_mask_2[seg_mask.astype(int) > 1] = 1
    seg_mask_3 = np.zeros((1, 160, 192, 160))
    seg_mask_3[seg_mask.astype(int) > 2] = 1
    seg_mask_3ch = np.concatenate(
        [seg_mask_1, seg_mask_2, seg_mask_3], axis=0).astype(int)

    # def scale_image(image_array):
    #     image_array = image_array.astype(float)
    #     image_array *= 255.0/image_array.max() # convert to 8-bit pixel values
    #     image_array = image_array.astype(int)
    #     return image_array

    # img_array_list = [a,seg_mask_1,seg_mask_2,seg_mask_3]
    # for img_array in img_array_list:
    #     img_array = scale_image(img_array)

    a = a.astype(float)
    a *= 255.0/a.max()  # convert to 8-bit pixel values
    a = np.rollaxis(a, 0, 2)
    a = a.astype('uint8')
#     print("unique flair values:", np.unique(a))

    seg_mask_1 = seg_mask_1.astype(float)
    seg_mask_1 *= 255.0/seg_mask_1.max()  # convert to 8-bit pixel values
    seg_mask_1 = np.rollaxis(seg_mask_1, 0, 2)
    seg_mask_1 = seg_mask_1.astype('uint8')
#     print("unique segment mask values:", np.unique(seg_mask_1))

    seg_mask_2 = seg_mask_2.astype(float)
    seg_mask_2 *= 255.0/seg_mask_2.max()  # convert to 8-bit pixel values
    seg_mask_2 = np.rollaxis(seg_mask_2, 0, 2)
    seg_mask_2 = seg_mask_2.astype('uint8')

    seg_mask_3 = seg_mask_3.astype(float)
    seg_mask_3 *= 255.0/seg_mask_3.max()  # convert to 8-bit pixel values
    seg_mask_3 = np.rollaxis(seg_mask_3, 0, 2)
    seg_mask_3 = seg_mask_3.astype('uint8')

#     ground_truth = np.concatenate(
#         [a, seg_mask_1, seg_mask_2, seg_mask_3], axis=0).astype('uint8')

#     print("unique flair + segment mask values:", np.unique(ground_truth))
    # shape.ground_truth
    # flairimg = flairimg.astype(float)
    # flairimg *= 255.0/flairimg.max() # convert to 8-bit pixel values
    # flairimg = flairimg.astype(int)
    # print(np.unique(flairimg))
#     print("final image shape:", ground_truth.shape)
#     imsave("./channel_split/"+testIDlist[i]+"ground_truth.tif", ground_truth, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"flair.tif", a, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"ground_truth_1.tif", seg_mask_1, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"ground_truth_2.tif", seg_mask_2, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"ground_truth_3.tif", seg_mask_3, 'imagej')

#     tiff = TIFF.open("./channel_split/"+testIDlist[i]+"ground_truth.tif", mode='w')
#     tiff.write_image(ground_truth)
#     tiff.close()
#     fi.write_multipage(ground_truth, "./channel_split/"+testIDlist[i]+"ground_truth.tif")
#     bioformats.write_image(pathname="./channel_split/"+testIDlist[i]+"ground_truth.tif", 
#                            pixels=ground_truth, 
#                            pixel_type=u'uint8',
#                            size_c=4, size_z=160, size_t=1,
#                            channel_names=None)

# javabridge.kill_vm()

# %% [markdown]
# ### Adding predictions:

# %%
import numpy as np
import copy
import nibabel as nib

from tifffile import imsave
from libtiff import TIFF

from skimage.io._plugins import freeimage_plugin as fi

# import javabridge
# import bioformats
# javabridge.start_vm(class_path=bioformats.JARS)

# your program goes here


# ID = testIDlist[i]
# for i in range(len(testIDlist)):
for i in range(2):

    print("current image:", i)

    ID = testIDlist[i]
    img1 = './data/' + ID + '_flair.nii.gz'
    img2 = './data/' + ID + '_t1.nii.gz'
    img3 = './data/' + ID + '_t1ce.nii.gz'
    img4 = './data/' + ID + '_t2.nii.gz'
    img5 = './data/' + ID + '_seg.nii.gz'

    newimage = nib.concat_images([img1, img2, img3, img4, img5])
    cropped = crop_img(newimage)
    img_array = np.array(cropped.dataobj)
    z = np.rollaxis(img_array, 3, 0)

    padded_image = np.zeros((5, 160, 192, 160))
    padded_image[:z.shape[0], :z.shape[1], :z.shape[2], :z.shape[3]] = z

    a, b, c, d, seg_mask = np.split(padded_image, 5, axis=0)

    images = np.concatenate([a, b, c, d], axis=0)

    # print("images shape:", images.shape, "images values:", np.unique(images.astype(int)))

    # split the channels:
    # seg_mask_1 = copy.deepcopy(seg_mask.astype(int))
    seg_mask_1 = np.zeros((1, 160, 192, 160))
    seg_mask_1[seg_mask.astype(int) > 0] = 1
    seg_mask_2 = np.zeros((1, 160, 192, 160))
    seg_mask_2[seg_mask.astype(int) > 1] = 1
    seg_mask_3 = np.zeros((1, 160, 192, 160))
    seg_mask_3[seg_mask.astype(int) > 2] = 1
    seg_mask_3ch = np.concatenate(
        [seg_mask_1, seg_mask_2, seg_mask_3], axis=0).astype(int)

    # def scale_image(image_array):
    #     image_array = image_array.astype(float)
    #     image_array *= 255.0/image_array.max() # convert to 8-bit pixel values
    #     image_array = image_array.astype(int)
    #     return image_array

    # img_array_list = [a,seg_mask_1,seg_mask_2,seg_mask_3]
    # for img_array in img_array_list:
    #     img_array = scale_image(img_array)

    a = a.astype(float)
    a *= 255.0/a.max()  # convert to 8-bit pixel values
    a = np.rollaxis(a, 0, 2) # cxyz -> xycz for imagej
    a = np.rollaxis(a, 0, 3) # switching x and z
    a = a.astype('uint8')
#     print("unique flair values:", np.unique(a))

    seg_mask_1 = seg_mask_1.astype(float)
    seg_mask_1 *= 255.0/seg_mask_1.max()  # convert to 8-bit pixel values
    seg_mask_1 = np.rollaxis(seg_mask_1, 0, 2) # cxyz -> xycz for imagej
    seg_mask_1 = np.rollaxis(seg_mask_1, 0, 3) # switching x and z
    seg_mask_1 = seg_mask_1.astype('uint8')
#     print("unique segment mask values:", np.unique(seg_mask_1))

    seg_mask_2 = seg_mask_2.astype(float)
    seg_mask_2 *= 255.0/seg_mask_2.max()  # convert to 8-bit pixel values
    seg_mask_2 = np.rollaxis(seg_mask_2, 0, 2) # cxyz -> xycz for imagej
    seg_mask_2 = np.rollaxis(seg_mask_2, 0, 3) # switching x and z
    seg_mask_2 = seg_mask_2.astype('uint8')

    seg_mask_3 = seg_mask_3.astype(float)
    seg_mask_3 *= 255.0/seg_mask_3.max()  # convert to 8-bit pixel values
    seg_mask_3 = np.rollaxis(seg_mask_3, 0, 2) # cxyz -> xycz for imagej
    seg_mask_3 = np.rollaxis(seg_mask_3, 0, 3) # switching x and z
    seg_mask_3 = seg_mask_3.astype('uint8')

#     ground_truth = np.concatenate(
#         [a, seg_mask_1, seg_mask_2, seg_mask_3], axis=0).astype('uint8')

#     print("unique flair + segment mask values:", np.unique(ground_truth))
    # shape.ground_truth
    # flairimg = flairimg.astype(float)
    # flairimg *= 255.0/flairimg.max() # convert to 8-bit pixel values
    # flairimg = flairimg.astype(int)
    # print(np.unique(flairimg))
#     print("final image shape:", ground_truth.shape)
#     imsave("./channel_split/"+testIDlist[i]+"ground_truth.tif", ground_truth, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"_flair.tif", a, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"_ground_truth_1.tif", seg_mask_1, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"_ground_truth_2.tif", seg_mask_2, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"_ground_truth_3.tif", seg_mask_3, 'imagej')

    imarray = pickle.load(open( "./channel_split/prediction_"+str(i)+".pkl", "rb" ) )

    prediction_thresh = copy.deepcopy(imarray)
    prediction_thresh[prediction_thresh < 0.5] = 0.
    prediction_thresh[prediction_thresh >= 0.5] = 1.
    prediction_thresh = prediction_thresh
    print(np.unique(prediction_thresh))
    prediction_thresh *= 255.0/prediction_thresh.max() # convert to 8-bit pixel values
    prediction_thresh = prediction_thresh.astype('uint8')
    prediction_thresh = np.rollaxis(prediction_thresh, 1, 3) # switching x and z; c will be taken care of in split
    print(np.unique(prediction_thresh))
    print(prediction_thresh.shape)

    pred1, pred2, pred3 = np.split(prediction_thresh, 3, axis=0)

    imsave("./channel_split/"+testIDlist[i]+"_predicted_1.tif", pred1, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"_predicted_2.tif", pred2, 'imagej')
    imsave("./channel_split/"+testIDlist[i]+"_predicted_3.tif", pred3, 'imagej')

    # print("images shape:", images.shape, "images values:", np.unique(images.astype(int)))

    # split the channels:
    # seg_mask_1 = copy.deepcopy(seg_mask.astype(int))


    #     seg_mask_3ch = np.concatenate(
#         [seg_mask_1, seg_mask_2, seg_mask_3], axis=0).astype(int)

#     imarray *= 255.0/imarray.max()

#     imsave("./channel_split/"+testIDlist[i]+"ground_truth_1.tif", seg_mask_1, 'imagej')
#     imsave("./channel_split/"+testIDlist[i]+"ground_truth_2.tif", seg_mask_2, 'imagej')
#     imsave("./channel_split/"+testIDlist[i]+"ground_truth_3.tif", seg_mask_3, 'imagej')
